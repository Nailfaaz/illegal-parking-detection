# %% [markdown]
# # Parking Detection Experiments
#
# ## Quick Start:
# 1. Set model path and video path
# 2. Run cells
# 3. Results saved automatically to `../output/experiments/`

# %%
import cv2
import numpy as np
from ultralytics import YOLO
import json
import os
import time
import pandas as pd
from datetime import datetime
from collections import defaultdict

class ParkingDetector:
    def __init__(self, model_path, video_path):
        self.model_path = model_path
        self.video_path = video_path
        self.model_name = os.path.splitext(os.path.basename(model_path))[0]
        self.video_name = os.path.splitext(os.path.basename(video_path))[0]
        
        # Find parking areas file
        self.areas_file = f'../output/parking-areas-{self.video_name}.json'
        
        # Results
        self.results = {
            'experiment_id': f"{self.model_name}_{self.video_name}_{datetime.now().strftime('%Y%m%d_%H%M%S')}",
            'model_path': model_path,
            'video_path': video_path,
            'areas_file': self.areas_file,
            'fps_data': [],
            'parked_vehicles': [],
            'tracking_issues': [],  # New: track flickering/lost detections
            'detection_stats': {},
            'performance': {}
        }
        
        print(f"Model: {self.model_name}")
        print(f"Video: {self.video_name}")
        print(f"Looking for areas: {self.areas_file}")
        
    def load_model_and_areas(self):
        # Load YOLO model
        print("\nLoading model...")
        self.model = YOLO(self.model_path)
        print(f"Model loaded: {self.model_name}")
        
        # Load parking areas
        if not os.path.exists(self.areas_file):
            print(f"Parking areas not found: {self.areas_file}")
            print("   Run define-park-areas.ipynb first!")
            return False
            
        with open(self.areas_file, 'r') as f:
            areas_data = json.load(f)
            
        self.parking_areas = [np.array(area) for area in areas_data['parking_areas']]
        print(f"Loaded {len(self.parking_areas)} parking areas")
        return True
        
    def is_in_parking_area(self, center_point):
        for i, area in enumerate(self.parking_areas):
            if cv2.pointPolygonTest(area, center_point, False) >= 0:
                return i
        return -1
        
    def run_detection(self, show_video=True):
        if not self.load_model_and_areas():
            return False
            
        print("\nStarting detection...")
        
        cap = cv2.VideoCapture(self.video_path)
        if not cap.isOpened():
            print(f"Cannot open video: {self.video_path}")
            return False
            
        # Video properties
        fps = cap.get(cv2.CAP_PROP_FPS)
        total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        
        # Tracking
        parking_timers = defaultdict(lambda: None)
        parked_vehicles = set()
        vehicle_classes = [2, 3, 5, 7]  # car, motorcycle, bus, truck
        parking_threshold = 30  # seconds
        
        # Flickering/tracking issue detection
        last_seen = {}  # track_id -> frame_count when last seen
        lost_vehicles = {}  # track_id -> frame_count when lost
        tracking_gaps = defaultdict(list)  # track_id -> list of (lost_frame, found_frame) gaps
        
        # Stats
        frame_count = 0
        total_detections = 0
        start_time = time.time()
        fps_times = []
        
        print(f"Video: {total_frames} frames, {fps:.1f} FPS")
        if show_video:
            print("Press 'q' to stop early, 's' to toggle video display")
        else:
            print("Processing without video display (faster)")
        print()
        
        display_video = show_video
        
        while True:
            frame_start = time.time()
            
            ret, frame = cap.read()
            if not ret:
                break
                
            frame_count += 1
            current_time = frame_count / fps
            
            # Run detection
            results = self.model.track(frame, persist=True, classes=vehicle_classes, verbose=False)
            
            # Draw parking areas on frame
            if display_video:
                display_frame = frame.copy()
                for i, area in enumerate(self.parking_areas):
                    cv2.polylines(display_frame, [area], True, (0, 255, 0), 2)
                    # Add area label
                    center = area.mean(axis=0).astype(int)
                    cv2.putText(display_frame, f"Area {i+1}", tuple(center), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
            
            # Process detections
            current_frame_vehicles = set()
            if results[0].boxes is not None and results[0].boxes.id is not None:
                boxes = results[0].boxes.xywh.cpu()
                track_ids = results[0].boxes.id.int().cpu().tolist()
                confidences = results[0].boxes.conf.float().cpu().tolist()
                
                for box, track_id, conf in zip(boxes, track_ids, confidences):
                    if conf < 0.5:
                        continue
                        
                    total_detections += 1
                    current_frame_vehicles.add(track_id)
                    
                    # Track flickering: check if this vehicle was lost and now found
                    if track_id in lost_vehicles:
                        lost_frame = lost_vehicles[track_id]
                        gap_duration = frame_count - lost_frame
                        tracking_gaps[track_id].append({
                            'lost_frame': lost_frame,
                            'found_frame': frame_count,
                            'gap_duration': gap_duration,
                            'gap_time_seconds': gap_duration / fps
                        })
                        print(f"Vehicle {track_id} re-tracked after {gap_duration} frames ({gap_duration/fps:.1f}s)")
                        del lost_vehicles[track_id]
                    
                    # Update last seen
                    last_seen[track_id] = frame_count
                    
                    # Get vehicle center and bounding box
                    x, y, w, h = box
                    center = (int(x), int(y))
                    
                    # Draw detection on frame
                    if display_video:
                        x1, y1 = int(x - w/2), int(y - h/2)
                        x2, y2 = int(x + w/2), int(y + h/2)
                        
                        # Check if in parking area
                        area_id = self.is_in_parking_area(center)
                        
                        if area_id >= 0:  # In parking area
                            # Check if vehicle is already marked as parked
                            if track_id in parked_vehicles:
                                color = (0, 0, 255)  # Red for parked vehicles
                                label = f"ID:{track_id} PARKED Area:{area_id+1}"
                            else:
                                color = (0, 255, 255)  # Yellow for vehicles in parking area but not yet parked
                                label = f"ID:{track_id} Area:{area_id+1}"
                        else:
                            color = (255, 0, 0)  # Blue for other vehicles
                            label = f"ID:{track_id}"
                            
                        cv2.rectangle(display_frame, (x1, y1), (x2, y2), color, 2)
                        cv2.putText(display_frame, label, (x1, y1-10), 
                                   cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)
                    
                    # Check if in parking area
                    area_id = self.is_in_parking_area(center)
                    
                    if area_id >= 0:  # In parking area
                        if track_id not in parking_timers:
                            parking_timers[track_id] = current_time
                            
                        # Check if parked long enough
                        parked_duration = current_time - parking_timers[track_id]
                        
                        if parked_duration >= parking_threshold and track_id not in parked_vehicles:
                            parked_vehicles.add(track_id)
                            
                            # Save parked vehicle data
                            self.results['parked_vehicles'].append({
                                'track_id': track_id,
                                'area_id': area_id + 1,
                                'time': current_time,
                                'frame': frame_count,
                                'duration': parked_duration
                            })
                            print(f"Vehicle {track_id} parked in area {area_id+1} after {parked_duration:.1f}s")
                    else:
                        # Vehicle left parking area
                        if track_id in parking_timers:
                            del parking_timers[track_id]
                        if track_id in parked_vehicles:
                            parked_vehicles.remove(track_id)
            
            # Detect lost vehicles (were seen recently but not in current frame)
            for vehicle_id, last_frame in list(last_seen.items()):
                if vehicle_id not in current_frame_vehicles and (frame_count - last_frame) == 1:
                    # Vehicle just lost tracking
                    lost_vehicles[vehicle_id] = frame_count
                    print(f"Vehicle {vehicle_id} lost tracking at frame {frame_count}")
            
            # Display video frame
            if display_video:
                # Add info overlay
                info_text = [
                    f"Frame: {frame_count}/{total_frames}",
                    f"FPS: {processing_fps:.1f}" if 'processing_fps' in locals() else "FPS: calculating...",
                    f"Detections: {total_detections}",
                    f"Parked: {len(parked_vehicles)}"
                ]
                
                for i, text in enumerate(info_text):
                    cv2.putText(display_frame, text, (10, 30 + i*25), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)
                
                cv2.imshow('Parking Detection', display_frame)
            
            # Calculate FPS
            frame_time = time.time() - frame_start
            processing_fps = 1.0 / frame_time if frame_time > 0 else 0
            fps_times.append(processing_fps)
            
            # Show progress
            if frame_count % 30 == 0:
                progress = (frame_count / total_frames) * 100
                avg_fps = sum(fps_times[-30:]) / min(30, len(fps_times))
                print(f"Progress: {progress:.1f}% | FPS: {avg_fps:.1f} | Parked: {len(parked_vehicles)}")
            
            # Check for quit or display toggle
            key = cv2.waitKey(1) & 0xFF
            if key == ord('q'):
                print("Stopped by user")
                break
            elif key == ord('s'):
                display_video = not display_video
                if display_video:
                    print("Video display enabled")
                else:
                    print("Video display disabled")
                    cv2.destroyAllWindows()
                
        cap.release()
        cv2.destroyAllWindows()
        
        # Calculate final stats
        total_time = time.time() - start_time
        avg_fps = sum(fps_times) / len(fps_times) if fps_times else 0
        
        # Process tracking issues data
        total_gaps = sum(len(gaps) for gaps in tracking_gaps.values())
        vehicles_with_gaps = len(tracking_gaps)
        
        # Convert tracking gaps to list format for JSON serialization
        tracking_issues_list = []
        for vehicle_id, gaps in tracking_gaps.items():
            for gap in gaps:
                tracking_issues_list.append({
                    'track_id': vehicle_id,
                    'lost_frame': gap['lost_frame'],
                    'found_frame': gap['found_frame'],
                    'gap_duration_frames': gap['gap_duration'],
                    'gap_duration_seconds': gap['gap_time_seconds']
                })
        
        self.results['fps_data'] = fps_times
        self.results['tracking_issues'] = tracking_issues_list
        self.results['detection_stats'] = {
            'total_frames': frame_count,
            'total_detections': total_detections,
            'unique_parked': len(parked_vehicles),
            'processing_time': total_time,
            'tracking_gaps_total': total_gaps,
            'vehicles_with_tracking_issues': vehicles_with_gaps
        }
        self.results['performance'] = {
            'avg_fps': avg_fps,
            'min_fps': min(fps_times) if fps_times else 0,
            'max_fps': max(fps_times) if fps_times else 0
        }
        
        print(f"\nDetection completed!")
        print(f"Processed {frame_count} frames in {total_time:.1f}s")
        print(f"Average FPS: {avg_fps:.1f}")
        print(f"Parked vehicles detected: {len(parked_vehicles)}")
        print(f"Tracking issues: {total_gaps} gaps in {vehicles_with_gaps} vehicles")
        
        return True
        
    def save_results(self):
        # Create output directory
        output_dir = f"../output/experiments/{self.results['experiment_id']}"
        os.makedirs(output_dir, exist_ok=True)
        
        # Save JSON results
        json_file = f"{output_dir}/results.json"
        with open(json_file, 'w') as f:
            json.dump(self.results, f, indent=2, default=str)
            
        # Save CSV summary
        csv_file = f"{output_dir}/summary.csv"
        summary_data = {
            'experiment_id': [self.results['experiment_id']],
            'model': [self.model_name],
            'video': [self.video_name],
            'avg_fps': [self.results['performance']['avg_fps']],
            'min_fps': [self.results['performance']['min_fps']],
            'max_fps': [self.results['performance']['max_fps']],
            'total_frames': [self.results['detection_stats']['total_frames']],
            'total_detections': [self.results['detection_stats']['total_detections']],
            'parked_vehicles': [self.results['detection_stats']['unique_parked']],
            'processing_time': [self.results['detection_stats']['processing_time']],
            'tracking_gaps': [self.results['detection_stats']['tracking_gaps_total']],
            'vehicles_with_issues': [self.results['detection_stats']['vehicles_with_tracking_issues']]
        }
        
        df = pd.DataFrame(summary_data)
        df.to_csv(csv_file, index=False)
        
        # Save parked vehicles details
        if self.results['parked_vehicles']:
            parked_df = pd.DataFrame(self.results['parked_vehicles'])
            parked_df.to_csv(f"{output_dir}/parked_vehicles.csv", index=False)
            
        # Save tracking issues details
        if self.results['tracking_issues']:
            tracking_df = pd.DataFrame(self.results['tracking_issues'])
            tracking_df.to_csv(f"{output_dir}/tracking_issues.csv", index=False)
            
        print(f"\nResults saved to: {output_dir}")
        files_list = "results.json, summary.csv"
        if self.results['parked_vehicles']:
            files_list += ", parked_vehicles.csv"
        if self.results['tracking_issues']:
            files_list += ", tracking_issues.csv"
        print(f"Files: {files_list}")
        
        return output_dir

# %%
# EXPERIMENT CONFIGURATION

# Model and dataset paths
model_path = '../yolo-model/yolov8n.pt'
video_path = '../dataset/video_1_cut50-00_01-00-00.mov'

print(f"Configuration:")
print(f"   Model: {model_path}")
print(f"   Video: {video_path}")

# Check files exist
if not os.path.exists(model_path):
    print(f"Model not found: {model_path}")
elif not os.path.exists(video_path):
    print(f"Video not found: {video_path}")
else:
    print(f"Files found, ready to run!")
# Out:
# Configuration:
#    Model: ../yolo-model/yolov8n.pt
#    Video: ../dataset/video_1_cut50-00_01-00-00.mov
# Files found, ready to run!

# %%
# RUN DETECTION EXPERIMENT

detector = ParkingDetector(model_path, video_path)

if detector.run_detection(show_video=True):  # Set to False for faster processing without video
    output_dir = detector.save_results()
    print(f"\nExperiment completed successfully!")
    print(f"Check results in: {output_dir}")
else:
    print(f"\nExperiment failed")
    print(f"   Make sure you've run define-park-areas.ipynb first")
# Out:
# Model: yolov8n
# Video: video_1_cut50-00_01-00-00
# Looking for areas: ../output/parking-areas-video_1_cut50-00_01-00-00.json
#
# Loading model...
# Model loaded: yolov8n
# Loaded 2 parking areas
#
# Starting detection...
# Video: 18000 frames, 30.0 FPS
# Press 'q' to stop early, 's' to toggle video display
#
# Vehicle 5 lost tracking at frame 2
# Vehicle 6 lost tracking at frame 2
# Vehicle 7 lost tracking at frame 2
# Vehicle 11 lost tracking at frame 4
# Vehicle 5 lost tracking at frame 2
# Vehicle 6 lost tracking at frame 2
# Vehicle 7 lost tracking at frame 2
# Vehicle 11 lost tracking at frame 4
# Vehicle 11 re-tracked after 1 frames (0.0s)
# Vehicle 11 re-tracked after 1 frames (0.0s)
# Vehicle 14 lost tracking at frame 8
# Vehicle 14 lost tracking at frame 8
# Vehicle 2 lost tracking at frame 12
# Vehicle 2 re-tracked after 2 frames (0.1s)
# Vehicle 12 lost tracking at frame 14
# Vehicle 2 lost tracking at frame 12
# Vehicle 2 re-tracked after 2 frames (0.1s)
# Vehicle 12 lost tracking at frame 14
# Vehicle 7 re-tracked after 17 frames (0.6s)
# Vehicle 8 lost tracking at frame 19
# Vehicle 7 lost tracking at frame 20
# Vehicle 18 lost tracking at frame 20
# Vehicle 7 re-tracked after 17 frames (0.6s)
# Vehicle 8 lost tracking at frame 19
# Vehicle 7 lost tracking at frame 20
# Vehicle 18 lost tracking at frame 20
# Vehicle 7 re-tracked after 4 frames (0.1s)
# Vehicle 2 lost tracking at frame 24
# Vehicle 6 re-tracked after 24 frames (0.8s)
# Vehicle 7 lost tracking at frame 26
# Vehicle 7 re-tracked after 4 frames (0.1s)
# Vehicle 2 lost tracking at frame 24
# Vehicle 6 re-tracked after 24 frames (0.8s)
# Vehicle 7 lost tracking at frame 26
# Vehicle 4 lost tracking at frame 27
# Vehicle 6 lost tracking at frame 27
# Vehicle 2 re-tracked after 4 frames (0.1s)
# Vehicle 4 re-tracked after 1 frames (0.0s)
# Vehicle 23 lost tracking at frame 28
# Vehicle 4 lost tracking at frame 27
# Vehicle 6 lost tracking at frame 27
# Vehicle 2 re-tracked after 4 frames (0.1s)
# Vehicle 4 re-tracked after 1 frames (0.0s)
# Vehicle 23 lost tracking at frame 28
# Vehicle 23 re-tracked after 2 frames (0.1s)
# Vehicle 2 lost tracking at frame 30
# Progress: 0.2% | FPS: 16.0 | Parked: 0
# Vehicle 7 re-tracked after 5 frames (0.2s)
# Vehicle 1 lost tracking at frame 31
# Vehicle 4 lost tracking at frame 31
# Vehicle 23 lost tracking at frame 31
# Vehicle 4 re-tracked after 1 frames (0.0s)
# Vehicle 23 re-tracked after 1 frames (0.0s)
# Vehicle 12 re-tracked after 18 frames (0.6s)
# Vehicle 7 lost tracking at frame 32
# Vehicle 32 lost tracking at frame 32
# Vehicle 28 lost tracking at frame 32
# Vehicle 23 re-tracked after 2 frames (0.1s)
# Vehicle 2 lost tracking at frame 30
# Progress: 0.2% | FPS: 16.0 | Parked: 0
# Vehicle 7 re-tracked after 5 frames (0.2s)
# Vehicle 1 lost tracking at frame 31
# Vehicle 4 lost tracking at frame 31
# Vehicle 23 lost tracking at frame 31
# Vehicle 4 re-tracked after 1 frames (0.0s)
# Vehicle 23 re-tracked after 1 frames (0.0s)
# Vehicle 12 re-tracked after 18 frames (0.6s)
# Vehicle 7 lost tracking at frame 32
# Vehicle 32 lost tracking at frame 32
# Vehicle 28 lost tracking at frame 32
# Vehicle 12 lost tracking at frame 34
# Vehicle 8 re-tracked after 16 frames (0.5s)
# Vehicle 18 re-tracked after 15 frames (0.5s)
# Vehicle 4 lost tracking at frame 36
# Vehicle 12 lost tracking at frame 34
# Vehicle 8 re-tracked after 16 frames (0.5s)
# Vehicle 18 re-tracked after 15 frames (0.5s)
# Vehicle 4 lost tracking at frame 36
# Vehicle 18 lost tracking at frame 37
# Vehicle 2 re-tracked after 8 frames (0.3s)
# Vehicle 7 re-tracked after 7 frames (0.2s)
# Vehicle 8 lost tracking at frame 39
# Vehicle 18 lost tracking at frame 37
# Vehicle 2 re-tracked after 8 frames (0.3s)
# Vehicle 7 re-tracked after 7 frames (0.2s)
# Vehicle 8 lost tracking at frame 39
# Vehicle 4 re-tracked after 5 frames (0.2s)
# Vehicle 7 lost tracking at frame 41
# Vehicle 23 lost tracking at frame 41
# Vehicle 8 re-tracked after 3 frames (0.1s)
# Vehicle 2 lost tracking at frame 42
# Vehicle 6 re-tracked after 16 frames (0.5s)
# Vehicle 7 re-tracked after 2 frames (0.1s)
# Vehicle 4 re-tracked after 5 frames (0.2s)
# Vehicle 7 lost tracking at frame 41
# Vehicle 23 lost tracking at frame 41
# Vehicle 8 re-tracked after 3 frames (0.1s)
# Vehicle 2 lost tracking at frame 42
# Vehicle 6 re-tracked after 16 frames (0.5s)
# Vehicle 7 re-tracked after 2 frames (0.1s)
# Vehicle 2 re-tracked after 2 frames (0.1s)
# Vehicle 6 lost tracking at frame 46
# Vehicle 7 lost tracking at frame 46
# Vehicle 2 re-tracked after 2 frames (0.1s)
# Vehicle 6 lost tracking at frame 46
# Vehicle 7 lost tracking at frame 46
# Vehicle 2 lost tracking at frame 47
# Vehicle 9 lost tracking at frame 47
# Vehicle 9 re-tracked after 1 frames (0.0s)
# Vehicle 18 re-tracked after 11 frames (0.4s)
# Vehicle 9 lost tracking at frame 49
# Vehicle 2 lost tracking at frame 47
# Vehicle 9 lost tracking at frame 47
# Vehicle 9 re-tracked after 1 frames (0.0s)
# Vehicle 18 re-tracked after 11 frames (0.4s)
# Vehicle 9 lost tracking at frame 49
# Vehicle 18 lost tracking at frame 52
# Vehicle 2 re-tracked after 7 frames (0.2s)
# Vehicle 18 lost tracking at frame 52
# Vehicle 2 re-tracked after 7 frames (0.2s)
# Vehicle 2 lost tracking at frame 56
# Vehicle 2 re-tracked after 1 frames (0.0s)
# Vehicle 2 lost tracking at frame 58
# Vehicle 2 re-tracked after 1 frames (0.0s)
# Vehicle 2 lost tracking at frame 56
# Vehicle 2 re-tracked after 1 frames (0.0s)
# Vehicle 2 lost tracking at frame 58
# Vehicle 2 re-tracked after 1 frames (0.0s)
# Progress: 0.3% | FPS: 16.9 | Parked: 0
# Vehicle 2 lost tracking at frame 61
# Vehicle 49 lost tracking at frame 62
# Progress: 0.3% | FPS: 16.9 | Parked: 0
# Vehicle 2 lost tracking at frame 61
# Vehicle 49 lost tracking at frame 62
# Vehicle 18 re-tracked after 16 frames (0.5s)
# Vehicle 18 re-tracked after 16 frames (0.5s)
# Vehicle 18 lost tracking at frame 71
# Vehicle 2 re-tracked after 12 frames (0.4s)
# Vehicle 18 lost tracking at frame 71
# Vehicle 2 re-tracked after 12 frames (0.4s)
# Vehicle 10 lost tracking at frame 74
# Vehicle 2 lost tracking at frame 76
# Vehicle 10 lost tracking at frame 74
# Vehicle 2 lost tracking at frame 76
# Vehicle 2 re-tracked after 1 frames (0.0s)
# Vehicle 2 lost tracking at frame 78
# Vehicle 2 re-tracked after 1 frames (0.0s)
# Vehicle 2 lost tracking at frame 78
# Vehicle 2 re-tracked after 4 frames (0.1s)
# Vehicle 2 lost tracking at frame 83
# Vehicle 2 re-tracked after 4 frames (0.1s)
# Vehicle 2 lost tracking at frame 83
# Vehicle 9 re-tracked after 37 frames (1.2s)
# Vehicle 9 lost tracking at frame 87
# Vehicle 9 re-tracked after 1 frames (0.0s)
# Vehicle 9 re-tracked after 37 frames (1.2s)
# Vehicle 9 lost tracking at frame 87
# Vehicle 9 re-tracked after 1 frames (0.0s)
# Vehicle 55 lost tracking at frame 90
# Progress: 0.5% | FPS: 15.1 | Parked: 0
# Vehicle 55 lost tracking at frame 90
# Progress: 0.5% | FPS: 15.1 | Parked: 0
# Vehicle 55 re-tracked after 8 frames (0.3s)
# Vehicle 9 lost tracking at frame 98
# Vehicle 9 re-tracked after 1 frames (0.0s)
# Vehicle 55 re-tracked after 8 frames (0.3s)
# Vehicle 9 lost tracking at frame 98
# Vehicle 9 re-tracked after 1 frames (0.0s)
# Vehicle 9 lost tracking at frame 103
# Vehicle 55 lost tracking at frame 104
# Vehicle 9 lost tracking at frame 103
# Vehicle 55 lost tracking at frame 104
# Vehicle 55 re-tracked after 6 frames (0.2s)
# Vehicle 55 lost tracking at frame 111
# Vehicle 55 re-tracked after 6 frames (0.2s)
# Vehicle 55 lost tracking at frame 111
# Vehicle 62 lost tracking at frame 119
# Progress: 0.7% | FPS: 14.6 | Parked: 0
# Vehicle 62 lost tracking at frame 119
# Progress: 0.7% | FPS: 14.6 | Parked: 0
# Vehicle 62 re-tracked after 4 frames (0.1s)
# Vehicle 10 re-tracked after 50 frames (1.7s)
# Vehicle 62 re-tracked after 4 frames (0.1s)
# Vehicle 10 re-tracked after 50 frames (1.7s)
# Vehicle 62 lost tracking at frame 127
# Vehicle 62 lost tracking at frame 127
# Vehicle 55 re-tracked after 19 frames (0.6s)
# Vehicle 62 re-tracked after 3 frames (0.1s)
# Vehicle 3 lost tracking at frame 132
# Vehicle 55 re-tracked after 19 frames (0.6s)
# Vehicle 62 re-tracked after 3 frames (0.1s)
# Vehicle 3 lost tracking at frame 132
# Vehicle 3 re-tracked after 1 frames (0.0s)
# Vehicle 9 re-tracked after 30 frames (1.0s)
# Vehicle 55 lost tracking at frame 133
# Vehicle 62 lost tracking at frame 133
# Vehicle 3 re-tracked after 1 frames (0.0s)
# Vehicle 9 re-tracked after 30 frames (1.0s)
# Vehicle 55 lost tracking at frame 133
# Vehicle 62 lost tracking at frame 133
# Vehicle 62 re-tracked after 2 frames (0.1s)
# Vehicle 3 lost tracking at frame 135
# Vehicle 10 lost tracking at frame 135
# Vehicle 10 re-tracked after 1 frames (0.0s)
# Vehicle 55 re-tracked after 3 frames (0.1s)
# Vehicle 62 re-tracked after 2 frames (0.1s)
# Vehicle 3 lost tracking at frame 135
# Vehicle 10 lost tracking at frame 135
# Vehicle 10 re-tracked after 1 frames (0.0s)
# Vehicle 55 re-tracked after 3 frames (0.1s)
# Vehicle 55 lost tracking at frame 138
# Vehicle 55 re-tracked after 1 frames (0.0s)
# Vehicle 55 lost tracking at frame 138
# Vehicle 55 re-tracked after 1 frames (0.0s)
# Vehicle 10 lost tracking at frame 144
# Vehicle 10 re-tracked after 1 frames (0.0s)
# Vehicle 10 lost tracking at frame 144
# Vehicle 10 re-tracked after 1 frames (0.0s)
# Progress: 0.8% | FPS: 13.4 | Parked: 0
# Progress: 0.8% | FPS: 13.4 | Parked: 0
# Vehicle 55 lost tracking at frame 156
# Vehicle 3 re-tracked after 23 frames (0.8s)
# Vehicle 55 re-tracked after 2 frames (0.1s)
# Vehicle 3 lost tracking at frame 159
# Vehicle 55 lost tracking at frame 156
# Vehicle 3 re-tracked after 23 frames (0.8s)
# Vehicle 55 re-tracked after 2 frames (0.1s)
# Vehicle 3 lost tracking at frame 159
# Vehicle 62 lost tracking at frame 161
# Vehicle 55 lost tracking at frame 162
# Vehicle 62 lost tracking at frame 161
# Vehicle 55 lost tracking at frame 162
# Vehicle 3 re-tracked after 4 frames (0.1s)
# Vehicle 3 re-tracked after 4 frames (0.1s)
# Vehicle 8 lost tracking at frame 166
# Vehicle 8 re-tracked after 1 frames (0.0s)
# Vehicle 62 re-tracked after 7 frames (0.2s)
# Vehicle 3 lost tracking at frame 168
# Vehicle 8 lost tracking at frame 168
# Vehicle 8 lost tracking at frame 166
# Vehicle 8 re-tracked after 1 frames (0.0s)
# Vehicle 62 re-tracked after 7 frames (0.2s)
# Vehicle 3 lost tracking at frame 168
# Vehicle 8 lost tracking at frame 168
# Vehicle 62 lost tracking at frame 171
# Vehicle 62 lost tracking at frame 171
# Vehicle 3 re-tracked after 6 frames (0.2s)
# Vehicle 8 re-tracked after 6 frames (0.2s)
# Vehicle 8 lost tracking at frame 175
# Vehicle 3 re-tracked after 6 frames (0.2s)
# Vehicle 8 re-tracked after 6 frames (0.2s)
# Vehicle 8 lost tracking at frame 175
# Vehicle 3 lost tracking at frame 176
# Vehicle 10 lost tracking at frame 176
# Vehicle 3 re-tracked after 2 frames (0.1s)
# Vehicle 8 re-tracked after 3 frames (0.1s)
# Vehicle 3 lost tracking at frame 176
# Vehicle 10 lost tracking at frame 176
# Vehicle 3 re-tracked after 2 frames (0.1s)
# Vehicle 8 re-tracked after 3 frames (0.1s)
# Vehicle 3 lost tracking at frame 179
# Vehicle 8 lost tracking at frame 179
# Progress: 1.0% | FPS: 13.3 | Parked: 0
# Vehicle 3 lost tracking at frame 179
# Vehicle 8 lost tracking at frame 179
# Progress: 1.0% | FPS: 13.3 | Parked: 0
# Vehicle 62 re-tracked after 12 frames (0.4s)
# Vehicle 62 re-tracked after 12 frames (0.4s)
# Vehicle 8 re-tracked after 7 frames (0.2s)
# Vehicle 125 lost tracking at frame 186
# Vehicle 4 lost tracking at frame 187
# Vehicle 8 lost tracking at frame 187
# Vehicle 4 re-tracked after 1 frames (0.0s)
# Vehicle 118 lost tracking at frame 188
# Vehicle 8 re-tracked after 7 frames (0.2s)
# Vehicle 125 lost tracking at frame 186
# Vehicle 4 lost tracking at frame 187
# Vehicle 8 lost tracking at frame 187
# Vehicle 4 re-tracked after 1 frames (0.0s)
# Vehicle 118 lost tracking at frame 188
# Vehicle 3 re-tracked after 11 frames (0.4s)
# Vehicle 4 lost tracking at frame 190
# Vehicle 4 re-tracked after 1 frames (0.0s)
# Vehicle 8 re-tracked after 4 frames (0.1s)
# Vehicle 118 re-tracked after 3 frames (0.1s)
# Vehicle 3 re-tracked after 11 frames (0.4s)
# Vehicle 4 lost tracking at frame 190
# Vehicle 4 re-tracked after 1 frames (0.0s)
# Vehicle 8 re-tracked after 4 frames (0.1s)
# Vehicle 118 re-tracked after 3 frames (0.1s)
# Vehicle 4 lost tracking at frame 193
# Vehicle 8 lost tracking at frame 193
# Vehicle 118 lost tracking at frame 193
# Vehicle 62 lost tracking at frame 194
# Vehicle 4 lost tracking at frame 193
# Vehicle 8 lost tracking at frame 193
# Vehicle 118 lost tracking at frame 193
# Vehicle 62 lost tracking at frame 194
# Vehicle 118 re-tracked after 3 frames (0.1s)
# Vehicle 118 lost tracking at frame 198
# Vehicle 130 lost tracking at frame 198
# Vehicle 131 lost tracking at frame 198
# Vehicle 118 re-tracked after 3 frames (0.1s)
# Vehicle 118 lost tracking at frame 198
# Vehicle 130 lost tracking at frame 198
# Vehicle 131 lost tracking at frame 198
# Vehicle 118 re-tracked after 1 frames (0.0s)
# Vehicle 130 re-tracked after 1 frames (0.0s)
# Vehicle 62 re-tracked after 6 frames (0.2s)
# Vehicle 130 lost tracking at frame 200
# Vehicle 130 re-tracked after 1 frames (0.0s)
# Vehicle 118 re-tracked after 1 frames (0.0s)
# Vehicle 130 re-tracked after 1 frames (0.0s)
# Vehicle 62 re-tracked after 6 frames (0.2s)
# Vehicle 130 lost tracking at frame 200
# Vehicle 130 re-tracked after 1 frames (0.0s)
# Vehicle 118 lost tracking at frame 203
# Vehicle 118 lost tracking at frame 203
# Vehicle 133 lost tracking at frame 205
# Vehicle 133 lost tracking at frame 205
# Vehicle 133 re-tracked after 3 frames (0.1s)
# Vehicle 130 lost tracking at frame 209
# Vehicle 130 re-tracked after 1 frames (0.0s)
# Progress: 1.2% | FPS: 13.7 | Parked: 0
# Vehicle 133 re-tracked after 3 frames (0.1s)
# Vehicle 130 lost tracking at frame 209
# Vehicle 130 re-tracked after 1 frames (0.0s)
# Progress: 1.2% | FPS: 13.7 | Parked: 0
# Vehicle 130 lost tracking at frame 211
# Vehicle 8 re-tracked after 19 frames (0.6s)
# Vehicle 130 lost tracking at frame 211
# Vehicle 8 re-tracked after 19 frames (0.6s)
# Vehicle 62 lost tracking at frame 221
# Vehicle 62 re-tracked after 1 frames (0.0s)
# Vehicle 148 lost tracking at frame 222
# Vehicle 62 lost tracking at frame 221
# Vehicle 62 re-tracked after 1 frames (0.0s)
# Vehicle 148 lost tracking at frame 222
# Vehicle 133 lost tracking at frame 228
# Vehicle 133 re-tracked after 1 frames (0.0s)
# Vehicle 133 lost tracking at frame 230
# Vehicle 133 lost tracking at frame 228
# Vehicle 133 re-tracked after 1 frames (0.0s)
# Vehicle 133 lost tracking at frame 230
# Vehicle 10 re-tracked after 56 frames (1.9s)
# Vehicle 133 re-tracked after 2 frames (0.1s)
# Vehicle 10 lost tracking at frame 233
# Vehicle 133 lost tracking at frame 233
# Vehicle 10 re-tracked after 1 frames (0.0s)
# Vehicle 161 lost tracking at frame 234
# Vehicle 10 re-tracked after 56 frames (1.9s)
# Vehicle 133 re-tracked after 2 frames (0.1s)
# Vehicle 10 lost tracking at frame 233
# Vehicle 133 lost tracking at frame 233
# Vehicle 10 re-tracked after 1 frames (0.0s)
# Vehicle 161 lost tracking at frame 234
# Vehicle 10 lost tracking at frame 235
# Vehicle 10 re-tracked after 1 frames (0.0s)
# Vehicle 10 lost tracking at frame 235
# Vehicle 10 re-tracked after 1 frames (0.0s)
# Progress: 1.3% | FPS: 14.6 | Parked: 0
# Vehicle 161 re-tracked after 7 frames (0.2s)
# Progress: 1.3% | FPS: 14.6 | Parked: 0
# Vehicle 161 re-tracked after 7 frames (0.2s)
# Vehicle 161 lost tracking at frame 243
# Vehicle 10 lost tracking at frame 244
# Vehicle 161 lost tracking at frame 243
# Vehicle 10 lost tracking at frame 244
# Vehicle 165 lost tracking at frame 246
# Vehicle 165 lost tracking at frame 246
# Vehicle 129 lost tracking at frame 256
# Vehicle 129 re-tracked after 1 frames (0.0s)
# Vehicle 129 lost tracking at frame 256
# Vehicle 129 re-tracked after 1 frames (0.0s)
# Vehicle 9 lost tracking at frame 259
# Vehicle 185 lost tracking at frame 261
# Vehicle 9 lost tracking at frame 259
# Vehicle 185 lost tracking at frame 261
# Vehicle 129 lost tracking at frame 268
# Vehicle 190 lost tracking at frame 268
# Vehicle 129 re-tracked after 1 frames (0.0s)
# Vehicle 190 re-tracked after 1 frames (0.0s)
# Vehicle 129 lost tracking at frame 270
# Vehicle 190 lost tracking at frame 270
# Progress: 1.5% | FPS: 14.7 | Parked: 0
# Vehicle 129 lost tracking at frame 268
# Vehicle 190 lost tracking at frame 268
# Vehicle 129 re-tracked after 1 frames (0.0s)
# Vehicle 190 re-tracked after 1 frames (0.0s)
# Vehicle 129 lost tracking at frame 270
# Vehicle 190 lost tracking at frame 270
# Progress: 1.5% | FPS: 14.7 | Parked: 0
# Vehicle 129 re-tracked after 1 frames (0.0s)
# Vehicle 158 lost tracking at frame 272
# Vehicle 129 re-tracked after 1 frames (0.0s)
# Vehicle 158 lost tracking at frame 272
# Vehicle 3 lost tracking at frame 276
# Vehicle 3 re-tracked after 1 frames (0.0s)
# Vehicle 10 re-tracked after 33 frames (1.1s)
# Vehicle 3 lost tracking at frame 276
# Vehicle 3 re-tracked after 1 frames (0.0s)
# Vehicle 10 re-tracked after 33 frames (1.1s)
# Vehicle 10 lost tracking at frame 279
# Vehicle 190 re-tracked after 10 frames (0.3s)
# Vehicle 10 lost tracking at frame 279
# Vehicle 190 re-tracked after 10 frames (0.3s)
# Vehicle 129 lost tracking at frame 282
# Vehicle 10 re-tracked after 4 frames (0.1s)
# Vehicle 129 re-tracked after 2 frames (0.1s)
# Vehicle 129 lost tracking at frame 282
# Vehicle 10 re-tracked after 4 frames (0.1s)
# Vehicle 129 re-tracked after 2 frames (0.1s)
# Vehicle 190 lost tracking at frame 286
# Vehicle 190 re-tracked after 1 frames (0.0s)
# Vehicle 129 lost tracking at frame 287
# Vehicle 190 lost tracking at frame 288
# Vehicle 129 re-tracked after 2 frames (0.1s)
# Vehicle 218 lost tracking at frame 289
# Vehicle 190 lost tracking at frame 286
# Vehicle 190 re-tracked after 1 frames (0.0s)
# Vehicle 129 lost tracking at frame 287
# Vehicle 190 lost tracking at frame 288
# Vehicle 129 re-tracked after 2 frames (0.1s)
# Vehicle 218 lost tracking at frame 289
# Vehicle 182 lost tracking at frame 290
# Vehicle 182 re-tracked after 1 frames (0.0s)
# Vehicle 212 lost tracking at frame 292
# Vehicle 182 lost tracking at frame 292
# Vehicle 219 lost tracking at frame 292
# Vehicle 182 lost tracking at frame 290
# Vehicle 182 re-tracked after 1 frames (0.0s)
# Vehicle 212 lost tracking at frame 292
# Vehicle 182 lost tracking at frame 292
# Vehicle 219 lost tracking at frame 292
# Vehicle 182 re-tracked after 1 frames (0.0s)
# Vehicle 182 lost tracking at frame 294
# Vehicle 219 re-tracked after 3 frames (0.1s)
# Vehicle 190 re-tracked after 7 frames (0.2s)
# Vehicle 182 re-tracked after 2 frames (0.1s)
# Vehicle 10 lost tracking at frame 296
# Vehicle 190 lost tracking at frame 296
# Vehicle 182 re-tracked after 1 frames (0.0s)
# Vehicle 182 lost tracking at frame 294
# Vehicle 219 re-tracked after 3 frames (0.1s)
# Vehicle 190 re-tracked after 7 frames (0.2s)
# Vehicle 182 re-tracked after 2 frames (0.1s)
# Vehicle 10 lost tracking at frame 296
# Vehicle 190 lost tracking at frame 296
# Vehicle 190 re-tracked after 2 frames (0.1s)
# Vehicle 219 lost tracking at frame 300
# Progress: 1.7% | FPS: 15.8 | Parked: 0
# Vehicle 190 re-tracked after 2 frames (0.1s)
# Vehicle 219 lost tracking at frame 300
# Progress: 1.7% | FPS: 15.8 | Parked: 0
# Vehicle 158 re-tracked after 29 frames (1.0s)
# Vehicle 219 re-tracked after 1 frames (0.0s)
# Vehicle 219 lost tracking at frame 303
# Vehicle 158 re-tracked after 29 frames (1.0s)
# Vehicle 219 re-tracked after 1 frames (0.0s)
# Vehicle 219 lost tracking at frame 303
# Vehicle 219 re-tracked after 3 frames (0.1s)
# Vehicle 158 lost tracking at frame 306
# Vehicle 158 re-tracked after 1 frames (0.0s)
# Vehicle 219 re-tracked after 3 frames (0.1s)
# Vehicle 158 lost tracking at frame 306
# Vehicle 158 re-tracked after 1 frames (0.0s)
# Vehicle 158 lost tracking at frame 310
# Vehicle 158 lost tracking at frame 310
# Vehicle 3 lost tracking at frame 319
# Vehicle 3 re-tracked after 1 frames (0.0s)
# Vehicle 219 lost tracking at frame 321
# Vehicle 3 lost tracking at frame 319
# Vehicle 3 re-tracked after 1 frames (0.0s)
# Vehicle 219 lost tracking at frame 321
# Vehicle 219 re-tracked after 2 frames (0.1s)
# Vehicle 3 lost tracking at frame 323
# Vehicle 219 re-tracked after 2 frames (0.1s)
# Vehicle 3 lost tracking at frame 323
# Vehicle 234 lost tracking at frame 330
# Vehicle 244 lost tracking at frame 330
# Progress: 1.8% | FPS: 17.1 | Parked: 0
# Vehicle 234 lost tracking at frame 330
# Vehicle 244 lost tracking at frame 330
# Progress: 1.8% | FPS: 17.1 | Parked: 0
# Vehicle 244 re-tracked after 4 frames (0.1s)
# Vehicle 244 lost tracking at frame 335
# Vehicle 10 re-tracked after 41 frames (1.4s)
# Vehicle 219 lost tracking at frame 337
# Vehicle 244 re-tracked after 4 frames (0.1s)
# Vehicle 244 lost tracking at frame 335
# Vehicle 10 re-tracked after 41 frames (1.4s)
# Vehicle 219 lost tracking at frame 337
# Vehicle 219 re-tracked after 1 frames (0.0s)
# Vehicle 129 lost tracking at frame 338
# Vehicle 244 re-tracked after 4 frames (0.1s)
# Vehicle 129 re-tracked after 2 frames (0.1s)
# Vehicle 244 lost tracking at frame 340
# Vehicle 219 re-tracked after 1 frames (0.0s)
# Vehicle 129 lost tracking at frame 338
# Vehicle 244 re-tracked after 4 frames (0.1s)
# Vehicle 129 re-tracked after 2 frames (0.1s)
# Vehicle 244 lost tracking at frame 340
# Vehicle 129 lost tracking at frame 342
# Vehicle 10 lost tracking at frame 343
# Vehicle 244 re-tracked after 4 frames (0.1s)
# Vehicle 225 lost tracking at frame 344
# Vehicle 129 lost tracking at frame 342
# Vehicle 10 lost tracking at frame 343
# Vehicle 244 re-tracked after 4 frames (0.1s)
# Vehicle 225 lost tracking at frame 344
# Vehicle 244 lost tracking at frame 345
# Vehicle 244 re-tracked after 1 frames (0.0s)
# Vehicle 182 lost tracking at frame 347
# Vehicle 219 lost tracking at frame 347
# Vehicle 244 lost tracking at frame 347
# Vehicle 158 re-tracked after 38 frames (1.3s)
# Vehicle 182 re-tracked after 1 frames (0.0s)
# Vehicle 219 re-tracked after 1 frames (0.0s)
# Vehicle 244 re-tracked after 1 frames (0.0s)
# Vehicle 244 lost tracking at frame 345
# Vehicle 244 re-tracked after 1 frames (0.0s)
# Vehicle 182 lost tracking at frame 347
# Vehicle 219 lost tracking at frame 347
# Vehicle 244 lost tracking at frame 347
# Vehicle 158 re-tracked after 38 frames (1.3s)
# Vehicle 182 re-tracked after 1 frames (0.0s)
# Vehicle 219 re-tracked after 1 frames (0.0s)
# Vehicle 244 re-tracked after 1 frames (0.0s)
# Vehicle 158 lost tracking at frame 350
# Vehicle 158 re-tracked after 1 frames (0.0s)
# Vehicle 244 lost tracking at frame 351
# Vehicle 158 lost tracking at frame 350
# Vehicle 158 re-tracked after 1 frames (0.0s)
# Vehicle 244 lost tracking at frame 351
# Vehicle 225 re-tracked after 9 frames (0.3s)
# Vehicle 3 re-tracked after 30 frames (1.0s)
# Vehicle 3 lost tracking at frame 354
# Vehicle 219 lost tracking at frame 354
# Vehicle 219 re-tracked after 1 frames (0.0s)
# Vehicle 62 lost tracking at frame 355
# Vehicle 3 re-tracked after 2 frames (0.1s)
# Vehicle 219 lost tracking at frame 356
# Vehicle 225 re-tracked after 9 frames (0.3s)
# Vehicle 3 re-tracked after 30 frames (1.0s)
# Vehicle 3 lost tracking at frame 354
# Vehicle 219 lost tracking at frame 354
# Vehicle 219 re-tracked after 1 frames (0.0s)
# Vehicle 62 lost tracking at frame 355
# Vehicle 3 re-tracked after 2 frames (0.1s)
# Vehicle 219 lost tracking at frame 356
# Vehicle 190 lost tracking at frame 358
# Vehicle 190 re-tracked after 1 frames (0.0s)
# Progress: 2.0% | FPS: 17.6 | Parked: 0
# Vehicle 219 re-tracked after 5 frames (0.2s)
# Vehicle 190 lost tracking at frame 358
# Vehicle 190 re-tracked after 1 frames (0.0s)
# Progress: 2.0% | FPS: 17.6 | Parked: 0
# Vehicle 219 re-tracked after 5 frames (0.2s)
# Vehicle 190 lost tracking at frame 363
# Vehicle 190 lost tracking at frame 363
# Vehicle 219 lost tracking at frame 368
# Vehicle 219 lost tracking at frame 368
# Vehicle 219 re-tracked after 3 frames (0.1s)
# Vehicle 219 re-tracked after 3 frames (0.1s)
# Vehicle 219 lost tracking at frame 376
# Vehicle 219 re-tracked after 1 frames (0.0s)
# Vehicle 219 lost tracking at frame 376
# Vehicle 219 re-tracked after 1 frames (0.0s)
# Vehicle 282 lost tracking at frame 390
# Progress: 2.2% | FPS: 15.6 | Parked: 0
# Vehicle 282 re-tracked after 1 frames (0.0s)
# Vehicle 219 lost tracking at frame 392
# Vehicle 282 lost tracking at frame 392
# Vehicle 282 lost tracking at frame 390
# Progress: 2.2% | FPS: 15.6 | Parked: 0
# Vehicle 282 re-tracked after 1 frames (0.0s)
# Vehicle 219 lost tracking at frame 392
# Vehicle 282 lost tracking at frame 392
# Vehicle 219 re-tracked after 2 frames (0.1s)
# Vehicle 3 lost tracking at frame 395
# Vehicle 219 lost tracking at frame 395
# Vehicle 219 re-tracked after 2 frames (0.1s)
# Vehicle 3 lost tracking at frame 395
# Vehicle 219 lost tracking at frame 395
# Vehicle 219 re-tracked after 2 frames (0.1s)
# Vehicle 3 re-tracked after 2 frames (0.1s)
# Vehicle 219 lost tracking at frame 398
# Vehicle 3 lost tracking at frame 399
# Vehicle 219 re-tracked after 2 frames (0.1s)
# Vehicle 3 re-tracked after 2 frames (0.1s)
# Vehicle 219 lost tracking at frame 398
# Vehicle 3 lost tracking at frame 399
# Vehicle 3 re-tracked after 2 frames (0.1s)
# Vehicle 3 re-tracked after 2 frames (0.1s)
# Vehicle 3 lost tracking at frame 404
# Vehicle 3 lost tracking at frame 404
# Vehicle 3 re-tracked after 6 frames (0.2s)
# Vehicle 3 re-tracked after 6 frames (0.2s)
# Vehicle 289 lost tracking at frame 416
# Vehicle 3 lost tracking at frame 418
# Vehicle 289 lost tracking at frame 416
# Vehicle 3 lost tracking at frame 418
# Vehicle 3 re-tracked after 1 frames (0.0s)
# Vehicle 294 lost tracking at frame 419
# Vehicle 294 re-tracked after 1 frames (0.0s)
# Progress: 2.3% | FPS: 15.0 | Parked: 0
# Vehicle 3 re-tracked after 1 frames (0.0s)
# Vehicle 294 lost tracking at frame 419
# Vehicle 294 re-tracked after 1 frames (0.0s)
# Progress: 2.3% | FPS: 15.0 | Parked: 0
# Vehicle 294 lost tracking at frame 423
# Vehicle 294 re-tracked after 1 frames (0.0s)
# Vehicle 294 lost tracking at frame 423
# Vehicle 294 re-tracked after 1 frames (0.0s)
# Vehicle 3 lost tracking at frame 436
# Vehicle 3 lost tracking at frame 436
# Vehicle 225 lost tracking at frame 440
# Vehicle 225 re-tracked after 2 frames (0.1s)
# Vehicle 225 lost tracking at frame 440
# Vehicle 225 re-tracked after 2 frames (0.1s)
# Vehicle 3 re-tracked after 8 frames (0.3s)
# Vehicle 3 lost tracking at frame 446
# Vehicle 3 re-tracked after 8 frames (0.3s)
# Vehicle 3 lost tracking at frame 446
# Vehicle 294 lost tracking at frame 448
# Vehicle 3 re-tracked after 4 frames (0.1s)
# Vehicle 294 re-tracked after 2 frames (0.1s)
# Progress: 2.5% | FPS: 16.0 | Parked: 0
# Vehicle 294 lost tracking at frame 448
# Vehicle 3 re-tracked after 4 frames (0.1s)
# Vehicle 294 re-tracked after 2 frames (0.1s)
# Progress: 2.5% | FPS: 16.0 | Parked: 0
# Vehicle 294 lost tracking at frame 457
# Vehicle 294 re-tracked after 1 frames (0.0s)
# Vehicle 294 lost tracking at frame 457
# Vehicle 294 re-tracked after 1 frames (0.0s)
# Vehicle 304 lost tracking at frame 461
# Vehicle 304 lost tracking at frame 461
# Vehicle 3 lost tracking at frame 466
# Vehicle 304 re-tracked after 8 frames (0.3s)
# Vehicle 3 lost tracking at frame 466
# Vehicle 304 re-tracked after 8 frames (0.3s)
# Vehicle 3 re-tracked after 7 frames (0.2s)
# Vehicle 3 lost tracking at frame 474
# Vehicle 304 lost tracking at frame 474
# Vehicle 3 re-tracked after 7 frames (0.2s)
# Vehicle 3 lost tracking at frame 474
# Vehicle 304 lost tracking at frame 474
# Progress: 2.7% | FPS: 18.1 | Parked: 0
# Vehicle 8 lost tracking at frame 481
# Progress: 2.7% | FPS: 18.1 | Parked: 0
# Vehicle 8 lost tracking at frame 481
# Vehicle 8 re-tracked after 3 frames (0.1s)
# Vehicle 8 re-tracked after 3 frames (0.1s)
# Vehicle 158 lost tracking at frame 490
# Vehicle 158 lost tracking at frame 490
# Vehicle 158 re-tracked after 4 frames (0.1s)
# Vehicle 3 re-tracked after 20 frames (0.7s)
# Vehicle 309 lost tracking at frame 494
# Vehicle 8 lost tracking at frame 496
# Vehicle 11 lost tracking at frame 496
# Vehicle 158 lost tracking at frame 496
# Vehicle 158 re-tracked after 4 frames (0.1s)
# Vehicle 3 re-tracked after 20 frames (0.7s)
# Vehicle 309 lost tracking at frame 494
# Vehicle 8 lost tracking at frame 496
# Vehicle 11 lost tracking at frame 496
# Vehicle 158 lost tracking at frame 496
# Vehicle 8 re-tracked after 2 frames (0.1s)
# Vehicle 158 re-tracked after 4 frames (0.1s)
# Vehicle 8 re-tracked after 2 frames (0.1s)
# Vehicle 158 re-tracked after 4 frames (0.1s)
# Vehicle 313 lost tracking at frame 501
# Vehicle 11 re-tracked after 8 frames (0.3s)
# Vehicle 158 lost tracking at frame 504
# Vehicle 313 lost tracking at frame 501
# Vehicle 11 re-tracked after 8 frames (0.3s)
# Vehicle 158 lost tracking at frame 504
# Vehicle 158 re-tracked after 1 frames (0.0s)
# Vehicle 313 re-tracked after 4 frames (0.1s)
# Vehicle 182 lost tracking at frame 505
# Vehicle 11 lost tracking at frame 506
# Vehicle 158 lost tracking at frame 507
# Vehicle 158 re-tracked after 1 frames (0.0s)
# Vehicle 313 re-tracked after 4 frames (0.1s)
# Vehicle 182 lost tracking at frame 505
# Vehicle 11 lost tracking at frame 506
# Vehicle 158 lost tracking at frame 507
# Progress: 2.8% | FPS: 17.3 | Parked: 0
# Vehicle 8 lost tracking at frame 513
# Progress: 2.8% | FPS: 17.3 | Parked: 0
# Vehicle 8 lost tracking at frame 513
# Vehicle 8 re-tracked after 1 frames (0.0s)
# Vehicle 8 re-tracked after 1 frames (0.0s)
# Vehicle 8 lost tracking at frame 519
# Vehicle 8 re-tracked after 1 frames (0.0s)
# Vehicle 309 re-tracked after 26 frames (0.9s)
# Vehicle 8 lost tracking at frame 521
# Vehicle 309 lost tracking at frame 521
# Vehicle 313 lost tracking at frame 521
# Vehicle 8 lost tracking at frame 519
# Vehicle 8 re-tracked after 1 frames (0.0s)
# Vehicle 309 re-tracked after 26 frames (0.9s)
# Vehicle 8 lost tracking at frame 521
# Vehicle 309 lost tracking at frame 521
# Vehicle 313 lost tracking at frame 521
# Vehicle 158 re-tracked after 15 frames (0.5s)
# Vehicle 158 lost tracking at frame 523
# Vehicle 8 re-tracked after 3 frames (0.1s)
# Vehicle 313 re-tracked after 3 frames (0.1s)
# Vehicle 10 re-tracked after 181 frames (6.0s)
# Vehicle 158 re-tracked after 15 frames (0.5s)
# Vehicle 158 lost tracking at frame 523
# Vehicle 8 re-tracked after 3 frames (0.1s)
# Vehicle 313 re-tracked after 3 frames (0.1s)
# Vehicle 10 re-tracked after 181 frames (6.0s)
# Vehicle 309 re-tracked after 7 frames (0.2s)
# Vehicle 313 lost tracking at frame 528
# Vehicle 309 lost tracking at frame 530
# Vehicle 309 re-tracked after 7 frames (0.2s)
# Vehicle 313 lost tracking at frame 528
# Vehicle 309 lost tracking at frame 530
# Vehicle 313 re-tracked after 5 frames (0.2s)
# Vehicle 10 lost tracking at frame 533
# Vehicle 313 lost tracking at frame 534
# Vehicle 313 re-tracked after 5 frames (0.2s)
# Vehicle 10 lost tracking at frame 533
# Vehicle 313 lost tracking at frame 534
# Vehicle 309 re-tracked after 10 frames (0.3s)
# Progress: 3.0% | FPS: 17.4 | Parked: 0
# Vehicle 313 re-tracked after 7 frames (0.2s)
# Vehicle 309 lost tracking at frame 541
# Vehicle 309 re-tracked after 1 frames (0.0s)
# Vehicle 309 re-tracked after 10 frames (0.3s)
# Progress: 3.0% | FPS: 17.4 | Parked: 0
# Vehicle 313 re-tracked after 7 frames (0.2s)
# Vehicle 309 lost tracking at frame 541
# Vehicle 309 re-tracked after 1 frames (0.0s)
# Vehicle 313 lost tracking at frame 544
# Vehicle 313 re-tracked after 1 frames (0.0s)
# Vehicle 312 lost tracking at frame 546
# Vehicle 313 lost tracking at frame 546
# Vehicle 313 lost tracking at frame 544
# Vehicle 313 re-tracked after 1 frames (0.0s)
# Vehicle 312 lost tracking at frame 546
# Vehicle 313 lost tracking at frame 546
# Vehicle 312 re-tracked after 2 frames (0.1s)
# Vehicle 309 lost tracking at frame 548
# Vehicle 309 re-tracked after 1 frames (0.0s)
# Vehicle 312 lost tracking at frame 549
# Vehicle 312 re-tracked after 1 frames (0.0s)
# Vehicle 313 re-tracked after 4 frames (0.1s)
# Vehicle 312 re-tracked after 2 frames (0.1s)
# Vehicle 309 lost tracking at frame 548
# Vehicle 309 re-tracked after 1 frames (0.0s)
# Vehicle 312 lost tracking at frame 549
# Vehicle 312 re-tracked after 1 frames (0.0s)
# Vehicle 313 re-tracked after 4 frames (0.1s)
# Vehicle 225 lost tracking at frame 552
# Vehicle 313 lost tracking at frame 552
# Vehicle 313 re-tracked after 1 frames (0.0s)
# Vehicle 312 lost tracking at frame 553
# Vehicle 338 lost tracking at frame 553
# Vehicle 312 re-tracked after 1 frames (0.0s)
# Vehicle 225 lost tracking at frame 552
# Vehicle 313 lost tracking at frame 552
# Vehicle 313 re-tracked after 1 frames (0.0s)
# Vehicle 312 lost tracking at frame 553
# Vehicle 338 lost tracking at frame 553
# Vehicle 312 re-tracked after 1 frames (0.0s)
# Vehicle 309 lost tracking at frame 556
# Vehicle 312 lost tracking at frame 556
# Vehicle 313 lost tracking at frame 556
# Vehicle 312 re-tracked after 1 frames (0.0s)
# Vehicle 313 re-tracked after 1 frames (0.0s)
# Vehicle 309 re-tracked after 1 frames (0.0s)
# Vehicle 309 lost tracking at frame 558
# Vehicle 313 lost tracking at frame 558
# Vehicle 309 lost tracking at frame 556
# Vehicle 312 lost tracking at frame 556
# Vehicle 313 lost tracking at frame 556
# Vehicle 312 re-tracked after 1 frames (0.0s)
# Vehicle 313 re-tracked after 1 frames (0.0s)
# Vehicle 309 re-tracked after 1 frames (0.0s)
# Vehicle 309 lost tracking at frame 558
# Vehicle 313 lost tracking at frame 558
# Vehicle 312 lost tracking at frame 559
# Vehicle 11 re-tracked after 55 frames (1.8s)
# Vehicle 11 lost tracking at frame 562
# Vehicle 333 lost tracking at frame 562
# Vehicle 312 lost tracking at frame 559
# Vehicle 11 re-tracked after 55 frames (1.8s)
# Vehicle 11 lost tracking at frame 562
# Vehicle 333 lost tracking at frame 562
# Vehicle 333 re-tracked after 3 frames (0.1s)
# Vehicle 11 re-tracked after 4 frames (0.1s)
# Vehicle 333 re-tracked after 3 frames (0.1s)
# Vehicle 11 re-tracked after 4 frames (0.1s)
# Progress: 3.2% | FPS: 17.7 | Parked: 0
# Progress: 3.2% | FPS: 17.7 | Parked: 0
# Vehicle 333 lost tracking at frame 573
# Vehicle 225 re-tracked after 22 frames (0.7s)
# Vehicle 333 re-tracked after 2 frames (0.1s)
# Vehicle 333 lost tracking at frame 573
# Vehicle 225 re-tracked after 22 frames (0.7s)
# Vehicle 333 re-tracked after 2 frames (0.1s)
# Vehicle 225 lost tracking at frame 583
# Vehicle 225 re-tracked after 2 frames (0.1s)
# Vehicle 225 lost tracking at frame 583
# Vehicle 225 re-tracked after 2 frames (0.1s)
# Vehicle 225 lost tracking at frame 586
# Vehicle 225 re-tracked after 1 frames (0.0s)
# Vehicle 225 lost tracking at frame 586
# Vehicle 225 re-tracked after 1 frames (0.0s)
# Vehicle 225 lost tracking at frame 590
# Vehicle 225 re-tracked after 1 frames (0.0s)
# Vehicle 225 lost tracking at frame 590
# Vehicle 225 re-tracked after 1 frames (0.0s)
# Vehicle 333 lost tracking at frame 598
# Progress: 3.3% | FPS: 16.6 | Parked: 0
# Vehicle 333 lost tracking at frame 598
# Progress: 3.3% | FPS: 16.6 | Parked: 0
# Vehicle 333 re-tracked after 5 frames (0.2s)
# Vehicle 333 re-tracked after 5 frames (0.2s)
# Vehicle 333 lost tracking at frame 606
# Vehicle 11 lost tracking at frame 607
# Vehicle 225 lost tracking at frame 607
# Vehicle 225 re-tracked after 1 frames (0.0s)
# Vehicle 333 lost tracking at frame 606
# Vehicle 11 lost tracking at frame 607
# Vehicle 225 lost tracking at frame 607
# Vehicle 225 re-tracked after 1 frames (0.0s)
# Vehicle 225 lost tracking at frame 610
# Vehicle 225 re-tracked after 1 frames (0.0s)
# Vehicle 383 lost tracking at frame 613
# Vehicle 225 lost tracking at frame 610
# Vehicle 225 re-tracked after 1 frames (0.0s)
# Vehicle 383 lost tracking at frame 613
# Vehicle 299 lost tracking at frame 618
# Vehicle 11 re-tracked after 12 frames (0.4s)
# Vehicle 299 re-tracked after 1 frames (0.0s)
# Vehicle 383 re-tracked after 6 frames (0.2s)
# Vehicle 225 lost tracking at frame 620
# Vehicle 299 lost tracking at frame 618
# Vehicle 11 re-tracked after 12 frames (0.4s)
# Vehicle 299 re-tracked after 1 frames (0.0s)
# Vehicle 383 re-tracked after 6 frames (0.2s)
# Vehicle 225 lost tracking at frame 620
# Progress: 3.5% | FPS: 16.6 | Parked: 0
# Vehicle 225 re-tracked after 13 frames (0.4s)
# Vehicle 3 lost tracking at frame 633
# Progress: 3.5% | FPS: 16.6 | Parked: 0
# Vehicle 225 re-tracked after 13 frames (0.4s)
# Vehicle 3 lost tracking at frame 633
# Vehicle 3 re-tracked after 1 frames (0.0s)
# Vehicle 225 lost tracking at frame 634
# Vehicle 299 lost tracking at frame 634
# Vehicle 3 lost tracking at frame 635
# Vehicle 3 re-tracked after 1 frames (0.0s)
# Vehicle 225 lost tracking at frame 634
# Vehicle 299 lost tracking at frame 634
# Vehicle 3 lost tracking at frame 635
# Vehicle 299 re-tracked after 4 frames (0.1s)
# Vehicle 383 lost tracking at frame 639
# Vehicle 299 lost tracking at frame 640
# Vehicle 299 re-tracked after 4 frames (0.1s)
# Vehicle 383 lost tracking at frame 639
# Vehicle 299 lost tracking at frame 640
# Vehicle 383 re-tracked after 2 frames (0.1s)
# Vehicle 396 lost tracking at frame 642
# Vehicle 3 re-tracked after 8 frames (0.3s)
# Vehicle 299 re-tracked after 3 frames (0.1s)
# Vehicle 383 re-tracked after 2 frames (0.1s)
# Vehicle 396 lost tracking at frame 642
# Vehicle 3 re-tracked after 8 frames (0.3s)
# Vehicle 299 re-tracked after 3 frames (0.1s)
# Vehicle 225 re-tracked after 10 frames (0.3s)
# Vehicle 299 lost tracking at frame 644
# Vehicle 299 re-tracked after 1 frames (0.0s)
# Vehicle 3 lost tracking at frame 645
# Vehicle 3 re-tracked after 2 frames (0.1s)
# Vehicle 225 lost tracking at frame 647
# Vehicle 225 re-tracked after 10 frames (0.3s)
# Vehicle 299 lost tracking at frame 644
# Vehicle 299 re-tracked after 1 frames (0.0s)
# Vehicle 3 lost tracking at frame 645
# Vehicle 3 re-tracked after 2 frames (0.1s)
# Vehicle 225 lost tracking at frame 647
# Vehicle 225 re-tracked after 3 frames (0.1s)
# Vehicle 3 lost tracking at frame 651
# Vehicle 3 re-tracked after 2 frames (0.1s)
# Vehicle 225 re-tracked after 3 frames (0.1s)
# Vehicle 3 lost tracking at frame 651
# Vehicle 3 re-tracked after 2 frames (0.1s)
# Vehicle 299 lost tracking at frame 655
# Vehicle 299 re-tracked after 1 frames (0.0s)
# Vehicle 299 lost tracking at frame 655
# Vehicle 299 re-tracked after 1 frames (0.0s)
# Vehicle 3 lost tracking at frame 658
# Progress: 3.7% | FPS: 17.3 | Parked: 0
# Vehicle 3 lost tracking at frame 658
# Progress: 3.7% | FPS: 17.3 | Parked: 0
# Vehicle 3 re-tracked after 3 frames (0.1s)
# Vehicle 332 lost tracking at frame 662
# Vehicle 3 re-tracked after 3 frames (0.1s)
# Vehicle 332 lost tracking at frame 662
# Vehicle 383 lost tracking at frame 665
# Vehicle 332 re-tracked after 4 frames (0.1s)
# Vehicle 383 lost tracking at frame 665
# Vehicle 332 re-tracked after 4 frames (0.1s)
# Vehicle 299 lost tracking at frame 672
# Vehicle 332 lost tracking at frame 672
# Vehicle 299 re-tracked after 1 frames (0.0s)
# Vehicle 332 re-tracked after 2 frames (0.1s)
# Vehicle 299 lost tracking at frame 674
# Vehicle 408 lost tracking at frame 674
# Vehicle 299 lost tracking at frame 672
# Vehicle 332 lost tracking at frame 672
# Vehicle 299 re-tracked after 1 frames (0.0s)
# Vehicle 332 re-tracked after 2 frames (0.1s)
# Vehicle 299 lost tracking at frame 674
# Vehicle 408 lost tracking at frame 674
# Vehicle 299 re-tracked after 1 frames (0.0s)
# Vehicle 407 lost tracking at frame 677
# Vehicle 332 lost tracking at frame 678
# Vehicle 299 re-tracked after 1 frames (0.0s)
# Vehicle 407 lost tracking at frame 677
# Vehicle 332 lost tracking at frame 678
# Vehicle 332 re-tracked after 1 frames (0.0s)
# Vehicle 332 re-tracked after 1 frames (0.0s)
# Vehicle 3 lost tracking at frame 684
# Vehicle 332 lost tracking at frame 685
# Vehicle 332 re-tracked after 1 frames (0.0s)
# Vehicle 3 lost tracking at frame 684
# Vehicle 332 lost tracking at frame 685
# Vehicle 332 re-tracked after 1 frames (0.0s)
# Progress: 3.8% | FPS: 17.4 | Parked: 0
# Progress: 3.8% | FPS: 17.4 | Parked: 0
# Vehicle 385 lost tracking at frame 699
# Vehicle 423 lost tracking at frame 699
# Vehicle 3 re-tracked after 17 frames (0.6s)
# Vehicle 423 re-tracked after 2 frames (0.1s)
# Vehicle 385 lost tracking at frame 699
# Vehicle 423 lost tracking at frame 699
# Vehicle 3 re-tracked after 17 frames (0.6s)
# Vehicle 423 re-tracked after 2 frames (0.1s)
# Vehicle 299 lost tracking at frame 703
# Vehicle 299 re-tracked after 2 frames (0.1s)
# Vehicle 425 lost tracking at frame 705
# Vehicle 426 lost tracking at frame 705
# Vehicle 299 lost tracking at frame 703
# Vehicle 299 re-tracked after 2 frames (0.1s)
# Vehicle 425 lost tracking at frame 705
# Vehicle 426 lost tracking at frame 705
# Vehicle 425 re-tracked after 1 frames (0.0s)
# Vehicle 426 re-tracked after 2 frames (0.1s)
# Vehicle 425 re-tracked after 1 frames (0.0s)
# Vehicle 426 re-tracked after 2 frames (0.1s)
# Vehicle 332 lost tracking at frame 709
# Vehicle 425 lost tracking at frame 709
# Vehicle 426 lost tracking at frame 709
# Vehicle 425 re-tracked after 1 frames (0.0s)
# Vehicle 332 re-tracked after 1 frames (0.0s)
# Vehicle 8 lost tracking at frame 711
# Vehicle 294 lost tracking at frame 711
# Vehicle 425 lost tracking at frame 711
# Vehicle 332 lost tracking at frame 709
# Vehicle 425 lost tracking at frame 709
# Vehicle 426 lost tracking at frame 709
# Vehicle 425 re-tracked after 1 frames (0.0s)
# Vehicle 332 re-tracked after 1 frames (0.0s)
# Vehicle 8 lost tracking at frame 711
# Vehicle 294 lost tracking at frame 711
# Vehicle 425 lost tracking at frame 711
# Vehicle 8 re-tracked after 2 frames (0.1s)
# Vehicle 294 re-tracked after 3 frames (0.1s)
# Vehicle 8 re-tracked after 2 frames (0.1s)
# Vehicle 294 re-tracked after 3 frames (0.1s)
# Vehicle 294 lost tracking at frame 718
# Progress: 4.0% | FPS: 17.0 | Parked: 0
# Vehicle 294 lost tracking at frame 718
# Progress: 4.0% | FPS: 17.0 | Parked: 0
# Vehicle 425 re-tracked after 11 frames (0.4s)
# Vehicle 299 lost tracking at frame 723
# Vehicle 425 re-tracked after 11 frames (0.4s)
# Vehicle 299 lost tracking at frame 723
# Vehicle 425 lost tracking at frame 725
# Vehicle 299 re-tracked after 3 frames (0.1s)
# Vehicle 429 lost tracking at frame 727
# Vehicle 425 lost tracking at frame 725
# Vehicle 299 re-tracked after 3 frames (0.1s)
# Vehicle 429 lost tracking at frame 727
# Vehicle 425 re-tracked after 4 frames (0.1s)
# Vehicle 429 re-tracked after 2 frames (0.1s)
# Vehicle 429 lost tracking at frame 731
# Vehicle 425 re-tracked after 4 frames (0.1s)
# Vehicle 429 re-tracked after 2 frames (0.1s)
# Vehicle 429 lost tracking at frame 731
# Vehicle 429 re-tracked after 2 frames (0.1s)
# Vehicle 429 lost tracking at frame 734
# Vehicle 429 re-tracked after 2 frames (0.1s)
# Vehicle 429 lost tracking at frame 734
# Vehicle 299 lost tracking at frame 737
# Vehicle 332 lost tracking at frame 737
# Vehicle 299 lost tracking at frame 737
# Vehicle 332 lost tracking at frame 737
# Vehicle 332 re-tracked after 5 frames (0.2s)
# Vehicle 332 re-tracked after 5 frames (0.2s)
# Vehicle 423 lost tracking at frame 745
# Vehicle 423 re-tracked after 1 frames (0.0s)
# Vehicle 425 lost tracking at frame 746
# Vehicle 423 lost tracking at frame 745
# Vehicle 423 re-tracked after 1 frames (0.0s)
# Vehicle 425 lost tracking at frame 746
# Vehicle 433 lost tracking at frame 749
# Vehicle 433 re-tracked after 1 frames (0.0s)
# Vehicle 332 lost tracking at frame 750
# Progress: 4.2% | FPS: 17.8 | Parked: 0
# Vehicle 425 re-tracked after 5 frames (0.2s)
# Vehicle 332 re-tracked after 1 frames (0.0s)
# Vehicle 433 lost tracking at frame 751
# Vehicle 299 re-tracked after 15 frames (0.5s)
# Vehicle 433 lost tracking at frame 749
# Vehicle 433 re-tracked after 1 frames (0.0s)
# Vehicle 332 lost tracking at frame 750
# Progress: 4.2% | FPS: 17.8 | Parked: 0
# Vehicle 425 re-tracked after 5 frames (0.2s)
# Vehicle 332 re-tracked after 1 frames (0.0s)
# Vehicle 433 lost tracking at frame 751
# Vehicle 299 re-tracked after 15 frames (0.5s)
# Vehicle 299 lost tracking at frame 753
# Vehicle 299 re-tracked after 1 frames (0.0s)
# Vehicle 299 lost tracking at frame 753
# Vehicle 299 re-tracked after 1 frames (0.0s)
# Vehicle 299 lost tracking at frame 757
# Vehicle 299 lost tracking at frame 757
# Vehicle 299 re-tracked after 4 frames (0.1s)
# Vehicle 299 lost tracking at frame 762
# Vehicle 299 re-tracked after 4 frames (0.1s)
# Vehicle 299 lost tracking at frame 762
# Vehicle 299 re-tracked after 4 frames (0.1s)
# Vehicle 299 lost tracking at frame 767
# Vehicle 299 re-tracked after 4 frames (0.1s)
# Vehicle 299 lost tracking at frame 767
# Vehicle 425 lost tracking at frame 773
# Vehicle 425 re-tracked after 2 frames (0.1s)
# Vehicle 423 lost tracking at frame 775
# Vehicle 425 lost tracking at frame 776
# Vehicle 425 lost tracking at frame 773
# Vehicle 425 re-tracked after 2 frames (0.1s)
# Vehicle 423 lost tracking at frame 775
# Vehicle 425 lost tracking at frame 776
# Vehicle 425 re-tracked after 3 frames (0.1s)
# Progress: 4.3% | FPS: 17.0 | Parked: 0
# Vehicle 425 re-tracked after 3 frames (0.1s)
# Progress: 4.3% | FPS: 17.0 | Parked: 0
# Vehicle 425 lost tracking at frame 784
# Vehicle 425 re-tracked after 1 frames (0.0s)
# Vehicle 425 lost tracking at frame 784
# Vehicle 425 re-tracked after 1 frames (0.0s)
# Vehicle 439 lost tracking at frame 788
# Vehicle 439 re-tracked after 2 frames (0.1s)
# Vehicle 439 lost tracking at frame 788
# Vehicle 439 re-tracked after 2 frames (0.1s)
# Vehicle 332 lost tracking at frame 794
# Vehicle 332 re-tracked after 1 frames (0.0s)
# Vehicle 438 lost tracking at frame 796
# Vehicle 332 lost tracking at frame 794
# Vehicle 332 re-tracked after 1 frames (0.0s)
# Vehicle 438 lost tracking at frame 796
# Vehicle 438 re-tracked after 2 frames (0.1s)
# Vehicle 438 re-tracked after 2 frames (0.1s)
# Vehicle 332 lost tracking at frame 807
# Vehicle 332 re-tracked after 2 frames (0.1s)
# Vehicle 438 lost tracking at frame 809
# Progress: 4.5% | FPS: 16.4 | Parked: 0
# Vehicle 332 lost tracking at frame 807
# Vehicle 332 re-tracked after 2 frames (0.1s)
# Vehicle 438 lost tracking at frame 809
# Progress: 4.5% | FPS: 16.4 | Parked: 0
# Vehicle 438 re-tracked after 2 frames (0.1s)
# Vehicle 332 lost tracking at frame 811
# Vehicle 332 re-tracked after 3 frames (0.1s)
# Vehicle 440 lost tracking at frame 814
# Vehicle 438 re-tracked after 2 frames (0.1s)
# Vehicle 332 lost tracking at frame 811
# Vehicle 332 re-tracked after 3 frames (0.1s)
# Vehicle 440 lost tracking at frame 814
# Vehicle 440 re-tracked after 1 frames (0.0s)
# Vehicle 332 lost tracking at frame 815
# Vehicle 440 re-tracked after 1 frames (0.0s)
# Vehicle 332 lost tracking at frame 815
# Vehicle 440 lost tracking at frame 818
# Vehicle 332 re-tracked after 4 frames (0.1s)
# Vehicle 440 lost tracking at frame 818
# Vehicle 332 re-tracked after 4 frames (0.1s)
# Vehicle 332 lost tracking at frame 822
# Vehicle 438 lost tracking at frame 823
# Vehicle 332 lost tracking at frame 822
# Vehicle 438 lost tracking at frame 823
# Vehicle 438 re-tracked after 2 frames (0.1s)
# Vehicle 332 re-tracked after 4 frames (0.1s)
# Vehicle 425 lost tracking at frame 827
# Vehicle 438 re-tracked after 2 frames (0.1s)
# Vehicle 332 re-tracked after 4 frames (0.1s)
# Vehicle 425 lost tracking at frame 827
# Vehicle 332 lost tracking at frame 828
# Vehicle 438 lost tracking at frame 829
# Vehicle 438 re-tracked after 1 frames (0.0s)
# Vehicle 332 re-tracked after 2 frames (0.1s)
# Vehicle 332 lost tracking at frame 828
# Vehicle 438 lost tracking at frame 829
# Vehicle 438 re-tracked after 1 frames (0.0s)
# Vehicle 332 re-tracked after 2 frames (0.1s)
# Vehicle 332 lost tracking at frame 831
# Vehicle 425 re-tracked after 6 frames (0.2s)
# Vehicle 332 lost tracking at frame 831
# Vehicle 425 re-tracked after 6 frames (0.2s)
# Vehicle 332 re-tracked after 3 frames (0.1s)
# Vehicle 425 lost tracking at frame 834
# Vehicle 332 lost tracking at frame 835
# Vehicle 332 re-tracked after 3 frames (0.1s)
# Vehicle 425 lost tracking at frame 834
# Vehicle 332 lost tracking at frame 835
# Vehicle 385 re-tracked after 139 frames (4.6s)
# Vehicle 385 lost tracking at frame 840
# Progress: 4.7% | FPS: 15.3 | Parked: 0
# Vehicle 385 re-tracked after 139 frames (4.6s)
# Vehicle 385 lost tracking at frame 840
# Progress: 4.7% | FPS: 15.3 | Parked: 0
# Vehicle 438 lost tracking at frame 842
# Vehicle 385 re-tracked after 5 frames (0.2s)
# Vehicle 438 lost tracking at frame 842
# Vehicle 385 re-tracked after 5 frames (0.2s)
# Vehicle 385 lost tracking at frame 853
# Vehicle 385 lost tracking at frame 853
# Vehicle 438 re-tracked after 17 frames (0.6s)
# Vehicle 438 re-tracked after 17 frames (0.6s)
# Vehicle 438 lost tracking at frame 863
# Vehicle 438 re-tracked after 2 frames (0.1s)
# Vehicle 438 lost tracking at frame 863
# Vehicle 438 re-tracked after 2 frames (0.1s)
# Vehicle 332 re-tracked after 34 frames (1.1s)
# Vehicle 438 lost tracking at frame 869
# Vehicle 438 re-tracked after 1 frames (0.0s)
# Progress: 4.8% | FPS: 17.0 | Parked: 0
# Vehicle 438 lost tracking at frame 871
# Vehicle 332 re-tracked after 34 frames (1.1s)
# Vehicle 438 lost tracking at frame 869
# Vehicle 438 re-tracked after 1 frames (0.0s)
# Progress: 4.8% | FPS: 17.0 | Parked: 0
# Vehicle 438 lost tracking at frame 871
# Vehicle 438 re-tracked after 4 frames (0.1s)
# Vehicle 438 lost tracking at frame 876
# Vehicle 438 re-tracked after 1 frames (0.0s)
# Vehicle 438 re-tracked after 4 frames (0.1s)
# Vehicle 438 lost tracking at frame 876
# Vehicle 438 re-tracked after 1 frames (0.0s)
# Vehicle 385 re-tracked after 30 frames (1.0s)
# Vehicle 332 lost tracking at frame 884
# Vehicle 385 re-tracked after 30 frames (1.0s)
# Vehicle 332 lost tracking at frame 884
# Vehicle 459 lost tracking at frame 889
# Vehicle 385 lost tracking at frame 891
# Vehicle 459 lost tracking at frame 889
# ...
# Vehicle 7081 lost tracking at frame 11366
# Vehicle 7101 re-tracked after 3 frames (0.1s)
# Vehicle 7081 re-tracked after 4 frames (0.1s)
# Vehicle 7081 lost tracking at frame 11366
# Progress: 63.2% | FPS: 16.9 | Parked: 15
# Progress: 63.2% | FPS: 16.9 | Parked: 15
# Vehicle 7083 lost tracking at frame 11377
# Vehicle 7083 lost tracking at frame 11377
# Vehicle 7083 re-tracked after 4 frames (0.1s)
# Vehicle 7083 re-tracked after 4 frames (0.1s)
# Vehicle 7083 lost tracking at frame 11384
# Vehicle 912 re-tracked after 65 frames (2.2s)
# Vehicle 7083 lost tracking at frame 11384
# Vehicle 912 re-tracked after 65 frames (2.2s)
# Progress: 63.3% | FPS: 16.5 | Parked: 15
# Progress: 63.3% | FPS: 16.5 | Parked: 15
# Vehicle 912 lost tracking at frame 11413
# Vehicle 7128 lost tracking at frame 11414
# Vehicle 7079 re-tracked after 70 frames (2.3s)
# Vehicle 6869 lost tracking at frame 11416
# Vehicle 912 lost tracking at frame 11413
# Vehicle 7128 lost tracking at frame 11414
# Vehicle 7079 re-tracked after 70 frames (2.3s)
# Vehicle 6869 lost tracking at frame 11416
# Vehicle 7079 lost tracking at frame 11418
# Vehicle 7128 re-tracked after 5 frames (0.2s)
# Vehicle 7079 lost tracking at frame 11418
# Vehicle 7128 re-tracked after 5 frames (0.2s)
# Vehicle 7128 lost tracking at frame 11421
# Vehicle 7134 lost tracking at frame 11421
# Vehicle 912 re-tracked after 9 frames (0.3s)
# Vehicle 7128 lost tracking at frame 11421
# Vehicle 7134 lost tracking at frame 11421
# Vehicle 912 re-tracked after 9 frames (0.3s)
# Progress: 63.5% | FPS: 17.5 | Parked: 15
# Progress: 63.5% | FPS: 17.5 | Parked: 15
# Vehicle 6055 re-tracked after 90 frames (3.0s)
# Vehicle 7141 lost tracking at frame 11434
# Vehicle 7134 re-tracked after 15 frames (0.5s)
# Vehicle 6055 re-tracked after 90 frames (3.0s)
# Vehicle 7141 lost tracking at frame 11434
# Vehicle 7134 re-tracked after 15 frames (0.5s)
# Vehicle 7145 lost tracking at frame 11438
# Vehicle 7145 lost tracking at frame 11438
# Vehicle 7141 re-tracked after 8 frames (0.3s)
# Vehicle 7145 re-tracked after 6 frames (0.2s)
# Vehicle 912 lost tracking at frame 11444
# Vehicle 7141 lost tracking at frame 11444
# Vehicle 7141 re-tracked after 8 frames (0.3s)
# Vehicle 7145 re-tracked after 6 frames (0.2s)
# Vehicle 912 lost tracking at frame 11444
# Vehicle 7141 lost tracking at frame 11444
# Vehicle 912 re-tracked after 1 frames (0.0s)
# Vehicle 912 re-tracked after 1 frames (0.0s)
# Vehicle 912 lost tracking at frame 11451
# Vehicle 912 lost tracking at frame 11451
# Vehicle 7145 lost tracking at frame 11456
# Vehicle 6055 lost tracking at frame 11458
# Vehicle 6055 re-tracked after 1 frames (0.0s)
# Vehicle 7145 lost tracking at frame 11456
# Vehicle 6055 lost tracking at frame 11458
# Vehicle 6055 re-tracked after 1 frames (0.0s)
# Vehicle 6055 lost tracking at frame 11460
# Progress: 63.7% | FPS: 15.9 | Parked: 15
# Vehicle 6055 re-tracked after 1 frames (0.0s)
# Vehicle 7145 re-tracked after 6 frames (0.2s)
# Vehicle 6055 lost tracking at frame 11460
# Progress: 63.7% | FPS: 15.9 | Parked: 15
# Vehicle 6055 re-tracked after 1 frames (0.0s)
# Vehicle 7145 re-tracked after 6 frames (0.2s)
# Vehicle 912 re-tracked after 15 frames (0.5s)
# Vehicle 6055 lost tracking at frame 11466
# Vehicle 912 lost tracking at frame 11467
# Vehicle 912 re-tracked after 1 frames (0.0s)
# Vehicle 7145 lost tracking at frame 11468
# Vehicle 7145 re-tracked after 1 frames (0.0s)
# Vehicle 912 re-tracked after 15 frames (0.5s)
# Vehicle 6055 lost tracking at frame 11466
# Vehicle 912 lost tracking at frame 11467
# Vehicle 912 re-tracked after 1 frames (0.0s)
# Vehicle 7145 lost tracking at frame 11468
# Vehicle 7145 re-tracked after 1 frames (0.0s)
# Vehicle 7157 lost tracking at frame 11477
# Vehicle 7157 re-tracked after 1 frames (0.0s)
# Vehicle 7157 lost tracking at frame 11477
# Vehicle 7157 re-tracked after 1 frames (0.0s)
# Progress: 63.8% | FPS: 17.3 | Parked: 15
# Vehicle 7067 lost tracking at frame 11493
# Vehicle 7157 lost tracking at frame 11493
# Progress: 63.8% | FPS: 17.3 | Parked: 15
# Vehicle 7067 lost tracking at frame 11493
# Vehicle 7157 lost tracking at frame 11493
# Vehicle 7157 re-tracked after 1 frames (0.0s)
# Vehicle 7157 lost tracking at frame 11496
# Vehicle 7157 re-tracked after 1 frames (0.0s)
# Vehicle 7157 lost tracking at frame 11496
# Vehicle 7067 re-tracked after 4 frames (0.1s)
# Vehicle 7157 re-tracked after 1 frames (0.0s)
# Vehicle 7134 lost tracking at frame 11497
# Vehicle 7067 lost tracking at frame 11498
# Vehicle 7067 re-tracked after 2 frames (0.1s)
# Vehicle 7067 re-tracked after 4 frames (0.1s)
# Vehicle 7157 re-tracked after 1 frames (0.0s)
# Vehicle 7134 lost tracking at frame 11497
# Vehicle 7067 lost tracking at frame 11498
# Vehicle 7067 re-tracked after 2 frames (0.1s)
# Vehicle 7067 lost tracking at frame 11501
# Vehicle 7145 lost tracking at frame 11501
# Vehicle 7067 lost tracking at frame 11501
# Vehicle 7145 lost tracking at frame 11501
# Vehicle 7067 re-tracked after 4 frames (0.1s)
# Vehicle 7067 lost tracking at frame 11506
# Vehicle 7067 re-tracked after 4 frames (0.1s)
# Vehicle 7067 lost tracking at frame 11506
# Vehicle 7067 re-tracked after 2 frames (0.1s)
# Vehicle 7145 re-tracked after 9 frames (0.3s)
# Vehicle 7134 re-tracked after 13 frames (0.4s)
# Vehicle 7182 lost tracking at frame 11510
# Vehicle 7067 re-tracked after 2 frames (0.1s)
# Vehicle 7145 re-tracked after 9 frames (0.3s)
# Vehicle 7134 re-tracked after 13 frames (0.4s)
# Vehicle 7182 lost tracking at frame 11510
# Vehicle 7067 lost tracking at frame 11512
# Vehicle 7145 lost tracking at frame 11512
# Vehicle 7145 re-tracked after 1 frames (0.0s)
# Vehicle 7134 lost tracking at frame 11513
# Vehicle 7165 lost tracking at frame 11513
# Vehicle 7067 lost tracking at frame 11512
# Vehicle 7145 lost tracking at frame 11512
# Vehicle 7145 re-tracked after 1 frames (0.0s)
# Vehicle 7134 lost tracking at frame 11513
# Vehicle 7165 lost tracking at frame 11513
# Vehicle 7067 re-tracked after 2 frames (0.1s)
# Vehicle 7134 re-tracked after 1 frames (0.0s)
# Vehicle 912 lost tracking at frame 11514
# Vehicle 7145 lost tracking at frame 11514
# Vehicle 7067 re-tracked after 2 frames (0.1s)
# Vehicle 7134 re-tracked after 1 frames (0.0s)
# Vehicle 912 lost tracking at frame 11514
# Vehicle 7145 lost tracking at frame 11514
# Vehicle 912 re-tracked after 2 frames (0.1s)
# Vehicle 7067 lost tracking at frame 11516
# Vehicle 7199 lost tracking at frame 11516
# Vehicle 7199 re-tracked after 1 frames (0.0s)
# Vehicle 912 lost tracking at frame 11517
# Vehicle 912 re-tracked after 2 frames (0.1s)
# Vehicle 7067 lost tracking at frame 11516
# Vehicle 7199 lost tracking at frame 11516
# Vehicle 7199 re-tracked after 1 frames (0.0s)
# Vehicle 912 lost tracking at frame 11517
# Vehicle 912 re-tracked after 2 frames (0.1s)
# Progress: 64.0% | FPS: 15.6 | Parked: 15
# Vehicle 912 lost tracking at frame 11521
# Vehicle 912 re-tracked after 2 frames (0.1s)
# Progress: 64.0% | FPS: 15.6 | Parked: 15
# Vehicle 912 lost tracking at frame 11521
# Vehicle 7215 lost tracking at frame 11528
# Vehicle 7215 lost tracking at frame 11528
# Vehicle 7199 lost tracking at frame 11530
# Vehicle 7199 lost tracking at frame 11530
# Vehicle 7199 re-tracked after 3 frames (0.1s)
# Vehicle 7134 lost tracking at frame 11533
# Vehicle 7199 re-tracked after 3 frames (0.1s)
# Vehicle 7134 lost tracking at frame 11533
# Vehicle 912 re-tracked after 14 frames (0.5s)
# Vehicle 912 re-tracked after 14 frames (0.5s)
# Vehicle 6055 re-tracked after 70 frames (2.3s)
# Vehicle 6055 re-tracked after 70 frames (2.3s)
# Vehicle 912 lost tracking at frame 11537
# Vehicle 7157 lost tracking at frame 11537
# Vehicle 912 lost tracking at frame 11537
# Vehicle 7157 lost tracking at frame 11537
# Vehicle 7219 lost tracking at frame 11538
# Vehicle 7219 lost tracking at frame 11538
# Vehicle 6055 lost tracking at frame 11541
# Vehicle 6055 lost tracking at frame 11541
# Vehicle 7157 re-tracked after 5 frames (0.2s)
# Vehicle 7157 re-tracked after 5 frames (0.2s)
# Vehicle 912 re-tracked after 13 frames (0.4s)
# Progress: 64.2% | FPS: 4.0 | Parked: 15
# Vehicle 912 re-tracked after 13 frames (0.4s)
# Progress: 64.2% | FPS: 4.0 | Parked: 15
# Vehicle 7165 re-tracked after 40 frames (1.3s)
# Vehicle 7165 re-tracked after 40 frames (1.3s)
# Vehicle 7213 lost tracking at frame 11554
# Vehicle 7213 lost tracking at frame 11554
# Vehicle 7213 re-tracked after 2 frames (0.1s)
# Vehicle 7213 re-tracked after 2 frames (0.1s)
# Vehicle 7157 lost tracking at frame 11557
# Vehicle 7213 lost tracking at frame 11557
# Vehicle 7157 lost tracking at frame 11557
# Vehicle 7213 lost tracking at frame 11557
# Vehicle 7213 re-tracked after 1 frames (0.0s)
# Vehicle 912 lost tracking at frame 11558
# Vehicle 912 re-tracked after 1 frames (0.0s)
# Vehicle 7213 re-tracked after 1 frames (0.0s)
# Vehicle 912 lost tracking at frame 11558
# Vehicle 912 re-tracked after 1 frames (0.0s)
# Vehicle 912 lost tracking at frame 11560
# Vehicle 7213 lost tracking at frame 11560
# Vehicle 7199 lost tracking at frame 11561
# Vehicle 912 lost tracking at frame 11560
# Vehicle 7213 lost tracking at frame 11560
# Vehicle 7199 lost tracking at frame 11561
# Vehicle 7213 re-tracked after 2 frames (0.1s)
# Vehicle 7199 re-tracked after 3 frames (0.1s)
# Vehicle 7165 lost tracking at frame 11564
# Vehicle 7213 re-tracked after 2 frames (0.1s)
# Vehicle 7199 re-tracked after 3 frames (0.1s)
# Vehicle 7165 lost tracking at frame 11564
# Vehicle 7213 lost tracking at frame 11565
# Vehicle 7213 re-tracked after 1 frames (0.0s)
# Vehicle 7199 lost tracking at frame 11566
# Vehicle 7213 lost tracking at frame 11565
# Vehicle 7213 re-tracked after 1 frames (0.0s)
# Vehicle 7199 lost tracking at frame 11566
# Vehicle 912 re-tracked after 8 frames (0.3s)
# Vehicle 912 lost tracking at frame 11569
# Vehicle 7213 lost tracking at frame 11569
# Vehicle 912 re-tracked after 1 frames (0.0s)
# Vehicle 7213 re-tracked after 1 frames (0.0s)
# Vehicle 912 re-tracked after 8 frames (0.3s)
# Vehicle 912 lost tracking at frame 11569
# Vehicle 7213 lost tracking at frame 11569
# Vehicle 912 re-tracked after 1 frames (0.0s)
# Vehicle 7213 re-tracked after 1 frames (0.0s)
# Vehicle 912 lost tracking at frame 11572
# Vehicle 912 lost tracking at frame 11572
# Vehicle 912 re-tracked after 6 frames (0.2s)
# Vehicle 7157 re-tracked after 21 frames (0.7s)
# Vehicle 7157 lost tracking at frame 11580
# Progress: 64.3% | FPS: 10.2 | Parked: 15
# Vehicle 912 re-tracked after 6 frames (0.2s)
# Vehicle 7157 re-tracked after 21 frames (0.7s)
# Vehicle 7157 lost tracking at frame 11580
# Progress: 64.3% | FPS: 10.2 | Parked: 15
# Vehicle 7134 re-tracked after 53 frames (1.8s)
# Vehicle 7213 lost tracking at frame 11586
# Vehicle 7213 re-tracked after 1 frames (0.0s)
# Vehicle 7134 lost tracking at frame 11587
# Vehicle 7265 lost tracking at frame 11588
# Vehicle 7134 re-tracked after 53 frames (1.8s)
# Vehicle 7213 lost tracking at frame 11586
# Vehicle 7213 re-tracked after 1 frames (0.0s)
# Vehicle 7134 lost tracking at frame 11587
# Vehicle 7265 lost tracking at frame 11588
# Vehicle 6055 re-tracked after 48 frames (1.6s)
# Vehicle 7265 re-tracked after 2 frames (0.1s)
# Vehicle 6055 re-tracked after 48 frames (1.6s)
# Vehicle 7265 re-tracked after 2 frames (0.1s)
# Vehicle 6055 lost tracking at frame 11593
# Vehicle 7250 lost tracking at frame 11593
# Vehicle 6055 lost tracking at frame 11593
# Vehicle 7250 lost tracking at frame 11593
# Vehicle 7250 re-tracked after 3 frames (0.1s)
# Vehicle 7134 re-tracked after 10 frames (0.3s)
# Vehicle 7213 lost tracking at frame 11597
# Vehicle 7250 lost tracking at frame 11599
# Vehicle 7250 re-tracked after 3 frames (0.1s)
# Vehicle 7134 re-tracked after 10 frames (0.3s)
# Vehicle 7213 lost tracking at frame 11597
# Vehicle 7250 lost tracking at frame 11599
# Vehicle 6055 re-tracked after 8 frames (0.3s)
# Vehicle 7250 re-tracked after 2 frames (0.1s)
# Vehicle 7265 lost tracking at frame 11601
# Vehicle 6055 lost tracking at frame 11602
# Vehicle 6055 re-tracked after 2 frames (0.1s)
# Vehicle 6055 re-tracked after 8 frames (0.3s)
# Vehicle 7250 re-tracked after 2 frames (0.1s)
# Vehicle 7265 lost tracking at frame 11601
# Vehicle 6055 lost tracking at frame 11602
# Vehicle 6055 re-tracked after 2 frames (0.1s)
# Vehicle 6055 lost tracking at frame 11605
# Vehicle 7265 re-tracked after 5 frames (0.2s)
# Vehicle 6055 lost tracking at frame 11605
# Vehicle 7265 re-tracked after 5 frames (0.2s)
# Vehicle 912 lost tracking at frame 11608
# Vehicle 912 re-tracked after 1 frames (0.0s)
# Vehicle 7250 lost tracking at frame 11609
# Vehicle 7250 re-tracked after 1 frames (0.0s)
# Vehicle 7265 lost tracking at frame 11610
# Vehicle 7272 lost tracking at frame 11610
# Progress: 64.5% | FPS: 16.3 | Parked: 15
# Vehicle 912 lost tracking at frame 11608
# Vehicle 912 re-tracked after 1 frames (0.0s)
# Vehicle 7250 lost tracking at frame 11609
# Vehicle 7250 re-tracked after 1 frames (0.0s)
# Vehicle 7265 lost tracking at frame 11610
# Vehicle 7272 lost tracking at frame 11610
# Progress: 64.5% | FPS: 16.3 | Parked: 15
# Vehicle 6055 re-tracked after 7 frames (0.2s)
# Vehicle 7105 lost tracking at frame 11612
# Vehicle 7265 re-tracked after 3 frames (0.1s)
# Vehicle 7105 re-tracked after 1 frames (0.0s)
# Vehicle 6055 lost tracking at frame 11613
# Vehicle 7250 lost tracking at frame 11613
# Vehicle 6055 re-tracked after 7 frames (0.2s)
# Vehicle 7105 lost tracking at frame 11612
# Vehicle 7265 re-tracked after 3 frames (0.1s)
# Vehicle 7105 re-tracked after 1 frames (0.0s)
# Vehicle 6055 lost tracking at frame 11613
# Vehicle 7250 lost tracking at frame 11613
# Vehicle 7265 lost tracking at frame 11617
# Vehicle 7265 re-tracked after 1 frames (0.0s)
# Vehicle 7105 lost tracking at frame 11618
# Vehicle 6778 lost tracking at frame 11619
# Vehicle 7265 lost tracking at frame 11617
# Vehicle 7265 re-tracked after 1 frames (0.0s)
# Vehicle 7105 lost tracking at frame 11618
# Vehicle 6778 lost tracking at frame 11619
# Vehicle 7213 re-tracked after 24 frames (0.8s)
# Vehicle 7134 lost tracking at frame 11621
# Vehicle 7213 re-tracked after 24 frames (0.8s)
# Vehicle 7134 lost tracking at frame 11621
# Vehicle 6055 re-tracked after 11 frames (0.4s)
# Vehicle 7105 re-tracked after 6 frames (0.2s)
# Vehicle 7134 re-tracked after 3 frames (0.1s)
# Vehicle 7213 lost tracking at frame 11624
# Vehicle 7265 lost tracking at frame 11625
# Vehicle 7265 re-tracked after 1 frames (0.0s)
# Vehicle 6055 re-tracked after 11 frames (0.4s)
# Vehicle 7105 re-tracked after 6 frames (0.2s)
# Vehicle 7134 re-tracked after 3 frames (0.1s)
# Vehicle 7213 lost tracking at frame 11624
# Vehicle 7265 lost tracking at frame 11625
# Vehicle 7265 re-tracked after 1 frames (0.0s)
# Vehicle 6055 lost tracking at frame 11629
# Vehicle 7105 lost tracking at frame 11629
# Vehicle 6055 lost tracking at frame 11629
# Vehicle 7105 lost tracking at frame 11629
# Vehicle 7105 re-tracked after 3 frames (0.1s)
# Vehicle 7105 lost tracking at frame 11634
# Vehicle 7105 re-tracked after 3 frames (0.1s)
# Vehicle 7105 lost tracking at frame 11634
# Vehicle 7213 re-tracked after 12 frames (0.4s)
# Vehicle 7134 lost tracking at frame 11636
# Vehicle 7134 re-tracked after 1 frames (0.0s)
# Vehicle 7213 lost tracking at frame 11637
# Vehicle 7213 re-tracked after 12 frames (0.4s)
# Vehicle 7134 lost tracking at frame 11636
# Vehicle 7134 re-tracked after 1 frames (0.0s)
# Vehicle 7213 lost tracking at frame 11637
# Progress: 64.7% | FPS: 14.9 | Parked: 15
# Vehicle 7265 lost tracking at frame 11642
# Progress: 64.7% | FPS: 14.9 | Parked: 15
# Vehicle 7265 lost tracking at frame 11642
# Stopped by user
#
# Detection completed!
# Processed 11643 frames in 937.6s
# Average FPS: 15.3
# Parked vehicles detected: 15
# Tracking issues: 2942 gaps in 483 vehicles
#
# Results saved to: ../output/experiments/yolov8n_video_1_cut50-00_01-00-00_20251001_173205
# Files: results.json, summary.csv, parked_vehicles.csv, tracking_issues.csv
#
# Experiment completed successfully!
# Check results in: ../output/experiments/yolov8n_video_1_cut50-00_01-00-00_20251001_173205
# Stopped by user
#
# Detection completed!
# Processed 11643 frames in 937.6s
# Average FPS: 15.3
# Parked vehicles detected: 15
# Tracking issues: 2942 gaps in 483 vehicles
#
# Results saved to: ../output/experiments/yolov8n_video_1_cut50-00_01-00-00_20251001_173205
# Files: results.json, summary.csv, parked_vehicles.csv, tracking_issues.csv
#
# Experiment completed successfully!
# Check results in: ../output/experiments/yolov8n_video_1_cut50-00_01-00-00_20251001_173205

# %%
# QUICK RESULTS DISPLAY

if 'detector' in locals() and detector.results['detection_stats']:
    print("\nEXPERIMENT RESULTS")
    print("=" * 40)
    
    stats = detector.results['detection_stats']
    perf = detector.results['performance']
    
    print(f"Model: {detector.model_name}")
    print(f"Video: {detector.video_name}")
    print(f"Processing Time: {stats['processing_time']:.1f}s")
    print(f"Frames Processed: {stats['total_frames']}")
    print(f"Average FPS: {perf['avg_fps']:.1f}")
    print(f"Total Detections: {stats['total_detections']}")
    print(f"Parked Vehicles: {stats['unique_parked']}")
    print(f"Tracking Issues: {stats.get('tracking_gaps_total', 0)} gaps in {stats.get('vehicles_with_tracking_issues', 0)} vehicles")
    
    if detector.results['parked_vehicles']:
        print(f"\nParked Vehicle Details:")
        for pv in detector.results['parked_vehicles']:
            print(f"   Vehicle {pv['track_id']}: Area {pv['area_id']}, {pv['duration']:.1f}s")
    
    if detector.results['tracking_issues']:
        print(f"\nTracking Issues Details:")
        for issue in detector.results['tracking_issues']:
            print(f"   Vehicle {issue['track_id']}: Lost at frame {issue['lost_frame']}, found at {issue['found_frame']} ({issue['gap_duration_seconds']:.1f}s gap)")
else:
    print("Run the detection experiment first!")

    #test
# Out:
# EXPERIMENT RESULTS
# ========================================
# Model: yolov8n
# Video: video_1_cut50-00_01-00-00
# Processing Time: 937.6s
# Frames Processed: 11643
# Average FPS: 15.3
# Total Detections: 65241
# Parked Vehicles: 15
# Tracking Issues: 2942 gaps in 483 vehicles
#
# Parked Vehicle Details:
#    Vehicle 8: Area 2, 30.0s
#    Vehicle 3: Area 2, 30.0s
#    Vehicle 11: Area 1, 30.0s
#    Vehicle 225: Area 2, 30.0s
#    Vehicle 385: Area 1, 32.6s
#    Vehicle 912: Area 2, 30.2s
#    Vehicle 943: Area 2, 30.0s
#    Vehicle 1447: Area 1, 30.0s
#    Vehicle 2007: Area 1, 30.0s
#    Vehicle 2063: Area 1, 33.7s
#    Vehicle 2729: Area 2, 30.0s
#    Vehicle 4231: Area 1, 30.0s
#    Vehicle 4256: Area 1, 44.0s
#    Vehicle 6012: Area 1, 30.0s
#    Vehicle 6055: Area 1, 30.5s
#
# Tracking Issues Details:
#    Vehicle 11: Lost at frame 4, found at 5 (0.0s gap)
#    Vehicle 11: Lost at frame 496, found at 504 (0.3s gap)
#    Vehicle 11: Lost at frame 506, found at 561 (1.8s gap)
#    Vehicle 11: Lost at frame 562, found at 566 (0.1s gap)
#    Vehicle 11: Lost at frame 607, found at 619 (0.4s gap)
#    Vehicle 11: Lost at frame 980, found at 985 (0.2s gap)
#    Vehicle 11: Lost at frame 996, found at 1021 (0.8s gap)
#    Vehicle 11: Lost at frame 1022, found at 1023 (0.0s gap)
#    Vehicle 11: Lost at frame 1027, found at 1032 (0.2s gap)
#    Vehicle 11: Lost at frame 1034, found at 1070 (1.2s gap)
#    Vehicle 11: Lost at frame 1358, found at 1368 (0.3s gap)
#    Vehicle 11: Lost at frame 1444, found at 1445 (0.0s gap)
#    Vehicle 11: Lost at frame 1448, found at 1456 (0.3s gap)
#    Vehicle 11: Lost at frame 1501, found at 1502 (0.0s gap)
#    Vehicle 11: Lost at frame 1525, found at 1540 (0.5s gap)
#    Vehicle 2: Lost at frame 12, found at 14 (0.1s gap)
#    Vehicle 2: Lost at frame 24, found at 28 (0.1s gap)
#    Vehicle 2: Lost at frame 30, found at 38 (0.3s gap)
#    Vehicle 2: Lost at frame 42, found at 44 (0.1s gap)
#    Vehicle 2: Lost at frame 47, found at 54 (0.2s gap)
#    Vehicle 2: Lost at frame 56, found at 57 (0.0s gap)
#    Vehicle 2: Lost at frame 58, found at 59 (0.0s gap)
#    Vehicle 2: Lost at frame 61, found at 73 (0.4s gap)
#    Vehicle 2: Lost at frame 76, found at 77 (0.0s gap)
#    Vehicle 2: Lost at frame 78, found at 82 (0.1s gap)
#    Vehicle 7: Lost at frame 2, found at 19 (0.6s gap)
#    Vehicle 7: Lost at frame 20, found at 24 (0.1s gap)
#    Vehicle 7: Lost at frame 26, found at 31 (0.2s gap)
#    Vehicle 7: Lost at frame 32, found at 39 (0.2s gap)
#    Vehicle 7: Lost at frame 41, found at 43 (0.1s gap)
#    Vehicle 6: Lost at frame 2, found at 26 (0.8s gap)
#    Vehicle 6: Lost at frame 27, found at 43 (0.5s gap)
#    Vehicle 4: Lost at frame 27, found at 28 (0.0s gap)
#    Vehicle 4: Lost at frame 31, found at 32 (0.0s gap)
#    Vehicle 4: Lost at frame 36, found at 41 (0.2s gap)
#    Vehicle 4: Lost at frame 187, found at 188 (0.0s gap)
#    Vehicle 4: Lost at frame 190, found at 191 (0.0s gap)
#    Vehicle 23: Lost at frame 28, found at 30 (0.1s gap)
#    Vehicle 23: Lost at frame 31, found at 32 (0.0s gap)
#    Vehicle 12: Lost at frame 14, found at 32 (0.6s gap)
#    Vehicle 8: Lost at frame 19, found at 35 (0.5s gap)
#    Vehicle 8: Lost at frame 39, found at 42 (0.1s gap)
#    Vehicle 8: Lost at frame 166, found at 167 (0.0s gap)
#    Vehicle 8: Lost at frame 168, found at 174 (0.2s gap)
#    Vehicle 8: Lost at frame 175, found at 178 (0.1s gap)
#    Vehicle 8: Lost at frame 179, found at 186 (0.2s gap)
#    Vehicle 8: Lost at frame 187, found at 191 (0.1s gap)
#    Vehicle 8: Lost at frame 193, found at 212 (0.6s gap)
#    Vehicle 8: Lost at frame 481, found at 484 (0.1s gap)
#    Vehicle 8: Lost at frame 496, found at 498 (0.1s gap)
#    Vehicle 8: Lost at frame 513, found at 514 (0.0s gap)
#    Vehicle 8: Lost at frame 519, found at 520 (0.0s gap)
#    Vehicle 8: Lost at frame 521, found at 524 (0.1s gap)
#    Vehicle 8: Lost at frame 711, found at 713 (0.1s gap)
#    Vehicle 8: Lost at frame 1017, found at 1018 (0.0s gap)
#    Vehicle 8: Lost at frame 1139, found at 1140 (0.0s gap)
#    Vehicle 8: Lost at frame 1189, found at 1191 (0.1s gap)
#    Vehicle 8: Lost at frame 1265, found at 1271 (0.2s gap)
#    Vehicle 8: Lost at frame 1272, found at 1276 (0.1s gap)
#    Vehicle 8: Lost at frame 1292, found at 1293 (0.0s gap)
#    Vehicle 8: Lost at frame 1380, found at 1381 (0.0s gap)
#    Vehicle 18: Lost at frame 20, found at 35 (0.5s gap)
#    Vehicle 18: Lost at frame 37, found at 48 (0.4s gap)
#    Vehicle 18: Lost at frame 52, found at 68 (0.5s gap)
#    Vehicle 9: Lost at frame 47, found at 48 (0.0s gap)
#    Vehicle 9: Lost at frame 49, found at 86 (1.2s gap)
#    Vehicle 9: Lost at frame 87, found at 88 (0.0s gap)
#    Vehicle 9: Lost at frame 98, found at 99 (0.0s gap)
#    Vehicle 9: Lost at frame 103, found at 133 (1.0s gap)
#    Vehicle 55: Lost at frame 90, found at 98 (0.3s gap)
#    Vehicle 55: Lost at frame 104, found at 110 (0.2s gap)
#    Vehicle 55: Lost at frame 111, found at 130 (0.6s gap)
#    Vehicle 55: Lost at frame 133, found at 136 (0.1s gap)
#    Vehicle 55: Lost at frame 138, found at 139 (0.0s gap)
#    Vehicle 55: Lost at frame 156, found at 158 (0.1s gap)
#    Vehicle 62: Lost at frame 119, found at 123 (0.1s gap)
#    Vehicle 62: Lost at frame 127, found at 130 (0.1s gap)
#    Vehicle 62: Lost at frame 133, found at 135 (0.1s gap)
#    Vehicle 62: Lost at frame 161, found at 168 (0.2s gap)
#    Vehicle 62: Lost at frame 171, found at 183 (0.4s gap)
#    Vehicle 62: Lost at frame 194, found at 200 (0.2s gap)
#    Vehicle 62: Lost at frame 221, found at 222 (0.0s gap)
#    Vehicle 10: Lost at frame 74, found at 124 (1.7s gap)
#    Vehicle 10: Lost at frame 135, found at 136 (0.0s gap)
#    Vehicle 10: Lost at frame 144, found at 145 (0.0s gap)
#    Vehicle 10: Lost at frame 176, found at 232 (1.9s gap)
#    Vehicle 10: Lost at frame 233, found at 234 (0.0s gap)
#    Vehicle 10: Lost at frame 235, found at 236 (0.0s gap)
#    Vehicle 10: Lost at frame 244, found at 277 (1.1s gap)
#    Vehicle 10: Lost at frame 279, found at 283 (0.1s gap)
#    Vehicle 10: Lost at frame 296, found at 337 (1.4s gap)
#    Vehicle 10: Lost at frame 343, found at 524 (6.0s gap)
#    Vehicle 3: Lost at frame 132, found at 133 (0.0s gap)
#    Vehicle 3: Lost at frame 135, found at 158 (0.8s gap)
#    Vehicle 3: Lost at frame 159, found at 163 (0.1s gap)
#    Vehicle 3: Lost at frame 168, found at 174 (0.2s gap)
#    Vehicle 3: Lost at frame 176, found at 178 (0.1s gap)
#    Vehicle 3: Lost at frame 179, found at 190 (0.4s gap)
#    Vehicle 3: Lost at frame 276, found at 277 (0.0s gap)
#    Vehicle 3: Lost at frame 319, found at 320 (0.0s gap)
#    Vehicle 3: Lost at frame 323, found at 353 (1.0s gap)
#    Vehicle 3: Lost at frame 354, found at 356 (0.1s gap)
#    Vehicle 3: Lost at frame 395, found at 397 (0.1s gap)
#    Vehicle 3: Lost at frame 399, found at 401 (0.1s gap)
#    Vehicle 3: Lost at frame 404, found at 410 (0.2s gap)
#    Vehicle 3: Lost at frame 418, found at 419 (0.0s gap)
#    Vehicle 3: Lost at frame 436, found at 444 (0.3s gap)
#    Vehicle 3: Lost at frame 446, found at 450 (0.1s gap)
#    Vehicle 3: Lost at frame 466, found at 473 (0.2s gap)
#    Vehicle 3: Lost at frame 474, found at 494 (0.7s gap)
#    Vehicle 3: Lost at frame 633, found at 634 (0.0s gap)
#    Vehicle 3: Lost at frame 635, found at 643 (0.3s gap)
#    Vehicle 3: Lost at frame 645, found at 647 (0.1s gap)
#    Vehicle 3: Lost at frame 651, found at 653 (0.1s gap)
#    Vehicle 3: Lost at frame 658, found at 661 (0.1s gap)
#    Vehicle 3: Lost at frame 684, found at 701 (0.6s gap)
#    Vehicle 3: Lost at frame 1007, found at 1009 (0.1s gap)
#    Vehicle 3: Lost at frame 1010, found at 1011 (0.0s gap)
#    Vehicle 3: Lost at frame 1021, found at 1022 (0.0s gap)
#    Vehicle 3: Lost at frame 1059, found at 1070 (0.4s gap)
#    Vehicle 3: Lost at frame 1072, found at 1076 (0.1s gap)
#    Vehicle 3: Lost at frame 1091, found at 1092 (0.0s gap)
#    Vehicle 3: Lost at frame 1094, found at 1103 (0.3s gap)
#    Vehicle 3: Lost at frame 1149, found at 1151 (0.1s gap)
#    Vehicle 3: Lost at frame 1196, found at 1198 (0.1s gap)
#    Vehicle 118: Lost at frame 188, found at 191 (0.1s gap)
#    Vehicle 118: Lost at frame 193, found at 196 (0.1s gap)
#    Vehicle 118: Lost at frame 198, found at 199 (0.0s gap)
#    Vehicle 130: Lost at frame 198, found at 199 (0.0s gap)
#    Vehicle 130: Lost at frame 200, found at 201 (0.0s gap)
#    Vehicle 130: Lost at frame 209, found at 210 (0.0s gap)
#    Vehicle 133: Lost at frame 205, found at 208 (0.1s gap)
#    Vehicle 133: Lost at frame 228, found at 229 (0.0s gap)
#    Vehicle 133: Lost at frame 230, found at 232 (0.1s gap)
#    Vehicle 161: Lost at frame 234, found at 241 (0.2s gap)
#    Vehicle 129: Lost at frame 256, found at 257 (0.0s gap)
#    Vehicle 129: Lost at frame 268, found at 269 (0.0s gap)
#    Vehicle 129: Lost at frame 270, found at 271 (0.0s gap)
#    Vehicle 129: Lost at frame 282, found at 284 (0.1s gap)
#    Vehicle 129: Lost at frame 287, found at 289 (0.1s gap)
#    Vehicle 129: Lost at frame 338, found at 340 (0.1s gap)
#    Vehicle 190: Lost at frame 268, found at 269 (0.0s gap)
#    Vehicle 190: Lost at frame 270, found at 280 (0.3s gap)
#    Vehicle 190: Lost at frame 286, found at 287 (0.0s gap)
#    Vehicle 190: Lost at frame 288, found at 295 (0.2s gap)
#    Vehicle 190: Lost at frame 296, found at 298 (0.1s gap)
#    Vehicle 190: Lost at frame 358, found at 359 (0.0s gap)
#    Vehicle 182: Lost at frame 290, found at 291 (0.0s gap)
#    Vehicle 182: Lost at frame 292, found at 293 (0.0s gap)
#    Vehicle 182: Lost at frame 294, found at 296 (0.1s gap)
#    Vehicle 182: Lost at frame 347, found at 348 (0.0s gap)
#    Vehicle 219: Lost at frame 292, found at 295 (0.1s gap)
#    Vehicle 219: Lost at frame 300, found at 301 (0.0s gap)
#    Vehicle 219: Lost at frame 303, found at 306 (0.1s gap)
#    Vehicle 219: Lost at frame 321, found at 323 (0.1s gap)
#    Vehicle 219: Lost at frame 337, found at 338 (0.0s gap)
#    Vehicle 219: Lost at frame 347, found at 348 (0.0s gap)
#    Vehicle 219: Lost at frame 354, found at 355 (0.0s gap)
#    Vehicle 219: Lost at frame 356, found at 361 (0.2s gap)
#    Vehicle 219: Lost at frame 368, found at 371 (0.1s gap)
#    Vehicle 219: Lost at frame 376, found at 377 (0.0s gap)
#    Vehicle 219: Lost at frame 392, found at 394 (0.1s gap)
#    Vehicle 219: Lost at frame 395, found at 397 (0.1s gap)
#    Vehicle 332: Lost at frame 822, found at 826 (0.1s gap)
#    Vehicle 332: Lost at frame 828, found at 830 (0.1s gap)
#    Vehicle 332: Lost at frame 831, found at 834 (0.1s gap)
#    Vehicle 332: Lost at frame 835, found at 869 (1.1s gap)
#    Vehicle 423: Lost at frame 699, found at 701 (0.1s gap)
#    Vehicle 423: Lost at frame 745, found at 746 (0.0s gap)
#    Vehicle 425: Lost at frame 705, found at 706 (0.0s gap)
#    Vehicle 425: Lost at frame 709, found at 710 (0.0s gap)
#    Vehicle 425: Lost at frame 711, found at 722 (0.4s gap)
#    Vehicle 425: Lost at frame 725, found at 729 (0.1s gap)
#    Vehicle 425: Lost at frame 746, found at 751 (0.2s gap)
#    Vehicle 425: Lost at frame 773, found at 775 (0.1s gap)
#    Vehicle 425: Lost at frame 776, found at 779 (0.1s gap)
#    Vehicle 425: Lost at frame 784, found at 785 (0.0s gap)
#    Vehicle 425: Lost at frame 827, found at 833 (0.2s gap)
#    Vehicle 426: Lost at frame 705, found at 707 (0.1s gap)
#    Vehicle 429: Lost at frame 727, found at 729 (0.1s gap)
#    Vehicle 429: Lost at frame 731, found at 733 (0.1s gap)
#    Vehicle 433: Lost at frame 749, found at 750 (0.0s gap)
#    Vehicle 439: Lost at frame 788, found at 790 (0.1s gap)
#    Vehicle 439: Lost at frame 976, found at 978 (0.1s gap)
#    Vehicle 439: Lost at frame 979, found at 985 (0.2s gap)
#    Vehicle 438: Lost at frame 796, found at 798 (0.1s gap)
#    Vehicle 438: Lost at frame 809, found at 811 (0.1s gap)
#    Vehicle 438: Lost at frame 823, found at 825 (0.1s gap)
#    Vehicle 438: Lost at frame 829, found at 830 (0.0s gap)
#    Vehicle 438: Lost at frame 842, found at 859 (0.6s gap)
#    Vehicle 438: Lost at frame 863, found at 865 (0.1s gap)
#    Vehicle 438: Lost at frame 869, found at 870 (0.0s gap)
#    Vehicle 438: Lost at frame 871, found at 875 (0.1s gap)
#    Vehicle 438: Lost at frame 876, found at 877 (0.0s gap)
#    Vehicle 438: Lost at frame 900, found at 901 (0.0s gap)
#    Vehicle 438: Lost at frame 1032, found at 1034 (0.1s gap)
#    Vehicle 440: Lost at frame 814, found at 815 (0.0s gap)
#    Vehicle 385: Lost at frame 699, found at 838 (4.6s gap)
#    Vehicle 385: Lost at frame 840, found at 845 (0.2s gap)
#    Vehicle 385: Lost at frame 853, found at 883 (1.0s gap)
#    Vehicle 385: Lost at frame 891, found at 894 (0.1s gap)
#    Vehicle 385: Lost at frame 899, found at 900 (0.0s gap)
#    Vehicle 385: Lost at frame 968, found at 970 (0.1s gap)
#    Vehicle 385: Lost at frame 971, found at 974 (0.1s gap)
#    Vehicle 385: Lost at frame 982, found at 985 (0.1s gap)
#    Vehicle 385: Lost at frame 986, found at 1006 (0.7s gap)
#    Vehicle 385: Lost at frame 1007, found at 1093 (2.9s gap)
#    Vehicle 385: Lost at frame 1126, found at 1130 (0.1s gap)
#    Vehicle 385: Lost at frame 1132, found at 1142 (0.3s gap)
#    Vehicle 385: Lost at frame 1143, found at 1144 (0.0s gap)
#    Vehicle 385: Lost at frame 1145, found at 1146 (0.0s gap)
#    Vehicle 385: Lost at frame 1149, found at 1159 (0.3s gap)
#    Vehicle 385: Lost at frame 1160, found at 1192 (1.1s gap)
#    Vehicle 385: Lost at frame 1194, found at 1198 (0.1s gap)
#    Vehicle 385: Lost at frame 1201, found at 1203 (0.1s gap)
#    Vehicle 385: Lost at frame 1204, found at 1206 (0.1s gap)
#    Vehicle 385: Lost at frame 1207, found at 1215 (0.3s gap)
#    Vehicle 385: Lost at frame 1216, found at 1218 (0.1s gap)
#    Vehicle 385: Lost at frame 1220, found at 1221 (0.0s gap)
#    Vehicle 385: Lost at frame 1223, found at 1309 (2.9s gap)
#    Vehicle 385: Lost at frame 1312, found at 1313 (0.0s gap)
#    Vehicle 385: Lost at frame 1317, found at 1319 (0.1s gap)
#    Vehicle 385: Lost at frame 1320, found at 1338 (0.6s gap)
#    Vehicle 385: Lost at frame 1339, found at 1341 (0.1s gap)
#    Vehicle 385: Lost at frame 1342, found at 1343 (0.0s gap)
#    Vehicle 385: Lost at frame 1353, found at 1424 (2.4s gap)
#    Vehicle 385: Lost at frame 1449, found at 1450 (0.0s gap)
#    Vehicle 385: Lost at frame 1451, found at 1477 (0.9s gap)
#    Vehicle 385: Lost at frame 1490, found at 1506 (0.5s gap)
#    Vehicle 385: Lost at frame 1507, found at 1523 (0.5s gap)
#    Vehicle 385: Lost at frame 1524, found at 1668 (4.8s gap)
#    Vehicle 385: Lost at frame 1669, found at 1676 (0.2s gap)
#    Vehicle 385: Lost at frame 1679, found at 1696 (0.6s gap)
#    Vehicle 385: Lost at frame 1698, found at 1699 (0.0s gap)
#    Vehicle 385: Lost at frame 1705, found at 1706 (0.0s gap)
#    Vehicle 385: Lost at frame 1708, found at 1719 (0.4s gap)
#    Vehicle 385: Lost at frame 1720, found at 1723 (0.1s gap)
#    Vehicle 385: Lost at frame 1726, found at 1727 (0.0s gap)
#    Vehicle 385: Lost at frame 1728, found at 1760 (1.1s gap)
#    Vehicle 385: Lost at frame 1761, found at 1793 (1.1s gap)
#    Vehicle 385: Lost at frame 1820, found at 1862 (1.4s gap)
#    Vehicle 385: Lost at frame 1868, found at 1899 (1.0s gap)
#    Vehicle 385: Lost at frame 1900, found at 1901 (0.0s gap)
#    Vehicle 385: Lost at frame 1905, found at 1907 (0.1s gap)
#    Vehicle 385: Lost at frame 1908, found at 1927 (0.6s gap)
#    Vehicle 385: Lost at frame 1928, found at 1941 (0.4s gap)
#    Vehicle 385: Lost at frame 1947, found at 1961 (0.5s gap)
#    Vehicle 385: Lost at frame 1972, found at 2160 (6.3s gap)
#    Vehicle 385: Lost at frame 2161, found at 2162 (0.0s gap)
#    Vehicle 385: Lost at frame 2164, found at 2171 (0.2s gap)
#    Vehicle 385: Lost at frame 2193, found at 2196 (0.1s gap)
#    Vehicle 385: Lost at frame 2197, found at 2204 (0.2s gap)
#    Vehicle 385: Lost at frame 2206, found at 2208 (0.1s gap)
#    Vehicle 385: Lost at frame 2215, found at 2221 (0.2s gap)
#    Vehicle 385: Lost at frame 2222, found at 2239 (0.6s gap)
#    Vehicle 385: Lost at frame 2250, found at 2299 (1.6s gap)
#    Vehicle 385: Lost at frame 2302, found at 2306 (0.1s gap)
#    Vehicle 385: Lost at frame 2308, found at 2323 (0.5s gap)
#    Vehicle 385: Lost at frame 2333, found at 2340 (0.2s gap)
#    Vehicle 385: Lost at frame 2349, found at 2350 (0.0s gap)
#    Vehicle 385: Lost at frame 2363, found at 2364 (0.0s gap)
#    Vehicle 385: Lost at frame 2365, found at 2366 (0.0s gap)
#    Vehicle 385: Lost at frame 2368, found at 2372 (0.1s gap)
#    Vehicle 385: Lost at frame 2373, found at 2514 (4.7s gap)
#    Vehicle 385: Lost at frame 2516, found at 2517 (0.0s gap)
#    Vehicle 385: Lost at frame 2518, found at 2521 (0.1s gap)
#    Vehicle 385: Lost at frame 2576, found at 2893 (10.6s gap)
#    Vehicle 385: Lost at frame 2897, found at 2898 (0.0s gap)
#    Vehicle 385: Lost at frame 2899, found at 2938 (1.3s gap)
#    Vehicle 385: Lost at frame 2960, found at 2963 (0.1s gap)
#    Vehicle 385: Lost at frame 2982, found at 3019 (1.2s gap)
#    Vehicle 385: Lost at frame 3023, found at 3027 (0.1s gap)
#    Vehicle 385: Lost at frame 3034, found at 3091 (1.9s gap)
#    Vehicle 459: Lost at frame 889, found at 914 (0.8s gap)
#    Vehicle 459: Lost at frame 916, found at 918 (0.1s gap)
#    Vehicle 459: Lost at frame 919, found at 940 (0.7s gap)
#    Vehicle 459: Lost at frame 944, found at 947 (0.1s gap)
#    Vehicle 459: Lost at frame 948, found at 956 (0.3s gap)
#    Vehicle 459: Lost at frame 957, found at 962 (0.2s gap)
#    Vehicle 459: Lost at frame 972, found at 973 (0.0s gap)
#    Vehicle 460: Lost at frame 931, found at 932 (0.0s gap)
#    Vehicle 477: Lost at frame 946, found at 947 (0.0s gap)
#    Vehicle 477: Lost at frame 961, found at 962 (0.0s gap)
#    Vehicle 477: Lost at frame 971, found at 975 (0.1s gap)
#    Vehicle 477: Lost at frame 987, found at 990 (0.1s gap)
#    Vehicle 502: Lost at frame 960, found at 961 (0.0s gap)
#    Vehicle 472: Lost at frame 932, found at 962 (1.0s gap)
#    Vehicle 472: Lost at frame 974, found at 976 (0.1s gap)
#    Vehicle 472: Lost at frame 980, found at 982 (0.1s gap)
#    Vehicle 472: Lost at frame 983, found at 991 (0.3s gap)
#    Vehicle 472: Lost at frame 998, found at 999 (0.0s gap)
#    Vehicle 492: Lost at frame 960, found at 972 (0.4s gap)
#    Vehicle 492: Lost at frame 973, found at 974 (0.0s gap)
#    Vehicle 492: Lost at frame 976, found at 980 (0.1s gap)
#    Vehicle 492: Lost at frame 982, found at 988 (0.2s gap)
#    Vehicle 492: Lost at frame 990, found at 994 (0.1s gap)
#    Vehicle 492: Lost at frame 995, found at 998 (0.1s gap)
#    Vehicle 518: Lost at frame 973, found at 979 (0.2s gap)
#    Vehicle 539: Lost at frame 994, found at 995 (0.0s gap)
#    Vehicle 539: Lost at frame 1003, found at 1008 (0.2s gap)
#    Vehicle 539: Lost at frame 1013, found at 1022 (0.3s gap)
#    Vehicle 539: Lost at frame 1030, found at 1038 (0.3s gap)
#    Vehicle 545: Lost at frame 1015, found at 1016 (0.0s gap)
#    Vehicle 545: Lost at frame 1019, found at 1020 (0.0s gap)
#    Vehicle 545: Lost at frame 1021, found at 1023 (0.1s gap)
#    Vehicle 545: Lost at frame 1024, found at 1027 (0.1s gap)
#    Vehicle 545: Lost at frame 1030, found at 1032 (0.1s gap)
#    Vehicle 545: Lost at frame 1039, found at 1040 (0.0s gap)
#    Vehicle 545: Lost at frame 1042, found at 1043 (0.0s gap)
#    Vehicle 545: Lost at frame 1044, found at 1046 (0.1s gap)
#    Vehicle 545: Lost at frame 1054, found at 1055 (0.0s gap)
#    Vehicle 545: Lost at frame 1057, found at 1074 (0.6s gap)
#    Vehicle 545: Lost at frame 1075, found at 1106 (1.0s gap)
#    Vehicle 559: Lost at frame 1013, found at 1019 (0.2s gap)
#    Vehicle 559: Lost at frame 1021, found at 1023 (0.1s gap)
#    Vehicle 559: Lost at frame 1024, found at 1030 (0.2s gap)
#    Vehicle 559: Lost at frame 1031, found at 1044 (0.4s gap)
#    Vehicle 559: Lost at frame 1048, found at 1050 (0.1s gap)
#    Vehicle 559: Lost at frame 1059, found at 1060 (0.0s gap)
#    Vehicle 588: Lost at frame 1031, found at 1036 (0.2s gap)
#    Vehicle 588: Lost at frame 1042, found at 1046 (0.1s gap)
#    Vehicle 588: Lost at frame 1055, found at 1056 (0.0s gap)
#    Vehicle 588: Lost at frame 1067, found at 1068 (0.0s gap)
#    Vehicle 588: Lost at frame 1078, found at 1079 (0.0s gap)
#    Vehicle 588: Lost at frame 1110, found at 1119 (0.3s gap)
#    Vehicle 592: Lost at frame 1034, found at 1036 (0.1s gap)
#    Vehicle 601: Lost at frame 1042, found at 1043 (0.0s gap)
#    Vehicle 601: Lost at frame 1047, found at 1051 (0.1s gap)
#    Vehicle 601: Lost at frame 1052, found at 1054 (0.1s gap)
#    Vehicle 653: Lost at frame 1066, found at 1068 (0.1s gap)
#    Vehicle 653: Lost at frame 1070, found at 1072 (0.1s gap)
#    Vehicle 653: Lost at frame 1078, found at 1079 (0.0s gap)
#    Vehicle 653: Lost at frame 1099, found at 1106 (0.2s gap)
#    Vehicle 653: Lost at frame 1108, found at 1110 (0.1s gap)
#    Vehicle 632: Lost at frame 1055, found at 1070 (0.5s gap)
#    Vehicle 632: Lost at frame 1078, found at 1082 (0.1s gap)
#    Vehicle 632: Lost at frame 1087, found at 1099 (0.4s gap)
#    Vehicle 632: Lost at frame 1103, found at 1108 (0.2s gap)
#    Vehicle 656: Lost at frame 1079, found at 1082 (0.1s gap)
#    Vehicle 682: Lost at frame 1090, found at 1091 (0.0s gap)
#    Vehicle 682: Lost at frame 1092, found at 1095 (0.1s gap)
#    Vehicle 943: Lost at frame 3593, found at 3595 (0.1s gap)
#    Vehicle 943: Lost at frame 3596, found at 3605 (0.3s gap)
#    Vehicle 943: Lost at frame 3608, found at 3613 (0.2s gap)
#    Vehicle 943: Lost at frame 3624, found at 3625 (0.0s gap)
#    Vehicle 943: Lost at frame 3626, found at 3645 (0.6s gap)
#    Vehicle 943: Lost at frame 3740, found at 3750 (0.3s gap)
#    Vehicle 943: Lost at frame 3996, found at 4007 (0.4s gap)
#    Vehicle 943: Lost at frame 4163, found at 4182 (0.6s gap)
#    Vehicle 961: Lost at frame 1502, found at 1542 (1.3s gap)
#    Vehicle 961: Lost at frame 1544, found at 1546 (0.1s gap)
#    Vehicle 961: Lost at frame 1558, found at 1563 (0.2s gap)
#    Vehicle 961: Lost at frame 1741, found at 1742 (0.0s gap)
#    Vehicle 1000: Lost at frame 1540, found at 1542 (0.1s gap)
#    Vehicle 1000: Lost at frame 1546, found at 1547 (0.0s gap)
#    Vehicle 1000: Lost at frame 1564, found at 1566 (0.1s gap)
#    Vehicle 1000: Lost at frame 1568, found at 1574 (0.2s gap)
#    Vehicle 1000: Lost at frame 1604, found at 1606 (0.1s gap)
#    Vehicle 1000: Lost at frame 1619, found at 1621 (0.1s gap)
#    Vehicle 1001: Lost at frame 1543, found at 1547 (0.1s gap)
#    Vehicle 1001: Lost at frame 1554, found at 1558 (0.1s gap)
#    Vehicle 1001: Lost at frame 1571, found at 1573 (0.1s gap)
#    Vehicle 1001: Lost at frame 1596, found at 1597 (0.0s gap)
#    Vehicle 1001: Lost at frame 1639, found at 1642 (0.1s gap)
#    Vehicle 988: Lost at frame 1546, found at 1551 (0.2s gap)
#    Vehicle 988: Lost at frame 1552, found at 1559 (0.2s gap)
#    Vehicle 1016: Lost at frame 1559, found at 1561 (0.1s gap)
#    Vehicle 1032: Lost at frame 1635, found at 1654 (0.6s gap)
#    Vehicle 1048: Lost at frame 1679, found at 1680 (0.0s gap)
#    Vehicle 1048: Lost at frame 1682, found at 1683 (0.0s gap)
#    Vehicle 1048: Lost at frame 1684, found at 1686 (0.1s gap)
#    Vehicle 1048: Lost at frame 1687, found at 1692 (0.2s gap)
#    Vehicle 1048: Lost at frame 1693, found at 1707 (0.5s gap)
#    Vehicle 1048: Lost at frame 1708, found at 1710 (0.1s gap)
#    Vehicle 1064: Lost at frame 1693, found at 1694 (0.0s gap)
#    Vehicle 1064: Lost at frame 1703, found at 1704 (0.0s gap)
#    Vehicle 1064: Lost at frame 1706, found at 1707 (0.0s gap)
#    Vehicle 1064: Lost at frame 1712, found at 1714 (0.1s gap)
#    Vehicle 1064: Lost at frame 1715, found at 1718 (0.1s gap)
#    Vehicle 1064: Lost at frame 1737, found at 1746 (0.3s gap)
#    Vehicle 1064: Lost at frame 1748, found at 1751 (0.1s gap)
#    Vehicle 1064: Lost at frame 1752, found at 1776 (0.8s gap)
#    Vehicle 1069: Lost at frame 1704, found at 1706 (0.1s gap)
#    Vehicle 1069: Lost at frame 1707, found at 1729 (0.7s gap)
#    Vehicle 1069: Lost at frame 1730, found at 1732 (0.1s gap)
#    Vehicle 1069: Lost at frame 1734, found at 1737 (0.1s gap)
#    Vehicle 1091: Lost at frame 1751, found at 1752 (0.0s gap)
#    Vehicle 1091: Lost at frame 1755, found at 1760 (0.2s gap)
#    Vehicle 1091: Lost at frame 1761, found at 1787 (0.9s gap)
#    Vehicle 912: Lost at frame 1769, found at 1771 (0.1s gap)
#    Vehicle 912: Lost at frame 1785, found at 1786 (0.0s gap)
#    Vehicle 912: Lost at frame 1787, found at 1788 (0.0s gap)
#    Vehicle 912: Lost at frame 1797, found at 1798 (0.0s gap)
#    Vehicle 912: Lost at frame 1805, found at 1807 (0.1s gap)
#    Vehicle 912: Lost at frame 1855, found at 1856 (0.0s gap)
#    Vehicle 912: Lost at frame 2117, found at 2118 (0.0s gap)
#    Vehicle 912: Lost at frame 2122, found at 2124 (0.1s gap)
#    Vehicle 912: Lost at frame 2256, found at 2258 (0.1s gap)
#    Vehicle 912: Lost at frame 2260, found at 2262 (0.1s gap)
#    Vehicle 912: Lost at frame 2308, found at 2309 (0.0s gap)
#    Vehicle 912: Lost at frame 2328, found at 2333 (0.2s gap)
#    Vehicle 912: Lost at frame 2334, found at 2340 (0.2s gap)
#    Vehicle 912: Lost at frame 2342, found at 2345 (0.1s gap)
#    Vehicle 912: Lost at frame 2358, found at 2366 (0.3s gap)
#    Vehicle 912: Lost at frame 2368, found at 2370 (0.1s gap)
#    Vehicle 912: Lost at frame 2471, found at 2472 (0.0s gap)
#    Vehicle 912: Lost at frame 2473, found at 2476 (0.1s gap)
#    Vehicle 912: Lost at frame 2478, found at 2479 (0.0s gap)
#    Vehicle 912: Lost at frame 2530, found at 2531 (0.0s gap)
#    Vehicle 912: Lost at frame 2572, found at 2603 (1.0s gap)
#    Vehicle 912: Lost at frame 2636, found at 2638 (0.1s gap)
#    Vehicle 912: Lost at frame 2677, found at 2679 (0.1s gap)
#    Vehicle 912: Lost at frame 2680, found at 2683 (0.1s gap)
#    Vehicle 912: Lost at frame 2685, found at 2692 (0.2s gap)
#    Vehicle 912: Lost at frame 2696, found at 2697 (0.0s gap)
#    Vehicle 912: Lost at frame 2728, found at 2731 (0.1s gap)
#    Vehicle 912: Lost at frame 2732, found at 2738 (0.2s gap)
#    Vehicle 912: Lost at frame 2816, found at 2820 (0.1s gap)
#    Vehicle 912: Lost at frame 2831, found at 2850 (0.6s gap)
#    Vehicle 912: Lost at frame 2853, found at 2861 (0.3s gap)
#    Vehicle 912: Lost at frame 2890, found at 2894 (0.1s gap)
#    Vehicle 912: Lost at frame 2899, found at 2901 (0.1s gap)
#    Vehicle 912: Lost at frame 2902, found at 2903 (0.0s gap)
#    Vehicle 912: Lost at frame 2917, found at 2919 (0.1s gap)
#    Vehicle 912: Lost at frame 3341, found at 3357 (0.5s gap)
#    Vehicle 912: Lost at frame 3359, found at 3379 (0.7s gap)
#    Vehicle 912: Lost at frame 3408, found at 3409 (0.0s gap)
#    Vehicle 912: Lost at frame 3413, found at 3459 (1.5s gap)
#    Vehicle 912: Lost at frame 3539, found at 3540 (0.0s gap)
#    Vehicle 912: Lost at frame 3583, found at 3584 (0.0s gap)
#    Vehicle 912: Lost at frame 3855, found at 3860 (0.2s gap)
#    Vehicle 912: Lost at frame 4022, found at 4023 (0.0s gap)
#    Vehicle 912: Lost at frame 4028, found at 4035 (0.2s gap)
#    Vehicle 912: Lost at frame 4037, found at 4041 (0.1s gap)
#    Vehicle 912: Lost at frame 4042, found at 4047 (0.2s gap)
#    Vehicle 912: Lost at frame 4049, found at 4052 (0.1s gap)
#    Vehicle 912: Lost at frame 4054, found at 4059 (0.2s gap)
#    Vehicle 912: Lost at frame 4062, found at 4066 (0.1s gap)
#    Vehicle 912: Lost at frame 4095, found at 4112 (0.6s gap)
#    Vehicle 912: Lost at frame 4120, found at 4122 (0.1s gap)
#    Vehicle 912: Lost at frame 4535, found at 4537 (0.1s gap)
#    Vehicle 912: Lost at frame 4538, found at 4544 (0.2s gap)
#    Vehicle 912: Lost at frame 4545, found at 4550 (0.2s gap)
#    Vehicle 912: Lost at frame 4612, found at 4613 (0.0s gap)
#    Vehicle 912: Lost at frame 4615, found at 4616 (0.0s gap)
#    Vehicle 912: Lost at frame 4754, found at 4756 (0.1s gap)
#    Vehicle 912: Lost at frame 4903, found at 4906 (0.1s gap)
#    Vehicle 912: Lost at frame 4910, found at 4915 (0.2s gap)
#    Vehicle 912: Lost at frame 4916, found at 4918 (0.1s gap)
#    Vehicle 912: Lost at frame 4933, found at 4934 (0.0s gap)
#    Vehicle 912: Lost at frame 4993, found at 4994 (0.0s gap)
#    Vehicle 912: Lost at frame 4995, found at 4996 (0.0s gap)
#    Vehicle 912: Lost at frame 5034, found at 5058 (0.8s gap)
#    Vehicle 912: Lost at frame 5059, found at 5060 (0.0s gap)
#    Vehicle 912: Lost at frame 5062, found at 5073 (0.4s gap)
#    Vehicle 912: Lost at frame 5083, found at 5085 (0.1s gap)
#    Vehicle 912: Lost at frame 5089, found at 5094 (0.2s gap)
#    Vehicle 912: Lost at frame 5095, found at 5099 (0.1s gap)
#    Vehicle 912: Lost at frame 5119, found at 5135 (0.5s gap)
#    Vehicle 912: Lost at frame 5156, found at 5157 (0.0s gap)
#    Vehicle 912: Lost at frame 5165, found at 5166 (0.0s gap)
#    Vehicle 912: Lost at frame 5171, found at 5182 (0.4s gap)
#    Vehicle 912: Lost at frame 5184, found at 5195 (0.4s gap)
#    Vehicle 912: Lost at frame 5386, found at 5389 (0.1s gap)
#    Vehicle 912: Lost at frame 5397, found at 5398 (0.0s gap)
#    Vehicle 912: Lost at frame 5400, found at 5401 (0.0s gap)
#    Vehicle 912: Lost at frame 5520, found at 5521 (0.0s gap)
#    Vehicle 912: Lost at frame 5630, found at 5633 (0.1s gap)
#    Vehicle 912: Lost at frame 5645, found at 5648 (0.1s gap)
#    Vehicle 912: Lost at frame 5659, found at 5662 (0.1s gap)
#    Vehicle 912: Lost at frame 5664, found at 5665 (0.0s gap)
#    Vehicle 912: Lost at frame 5666, found at 5669 (0.1s gap)
#    Vehicle 912: Lost at frame 5671, found at 5672 (0.0s gap)
#    Vehicle 912: Lost at frame 5673, found at 5674 (0.0s gap)
#    Vehicle 912: Lost at frame 5678, found at 5680 (0.1s gap)
#    Vehicle 912: Lost at frame 5681, found at 5718 (1.2s gap)
#    Vehicle 912: Lost at frame 5721, found at 5722 (0.0s gap)
#    Vehicle 912: Lost at frame 5736, found at 5742 (0.2s gap)
#    Vehicle 912: Lost at frame 5758, found at 5760 (0.1s gap)
#    Vehicle 912: Lost at frame 5761, found at 5762 (0.0s gap)
#    Vehicle 912: Lost at frame 5849, found at 5850 (0.0s gap)
#    Vehicle 912: Lost at frame 5867, found at 5876 (0.3s gap)
#    Vehicle 912: Lost at frame 5878, found at 5879 (0.0s gap)
#    Vehicle 912: Lost at frame 5881, found at 5882 (0.0s gap)
#    Vehicle 912: Lost at frame 5883, found at 5884 (0.0s gap)
#    Vehicle 912: Lost at frame 5885, found at 6032 (4.9s gap)
#    Vehicle 912: Lost at frame 6035, found at 6040 (0.2s gap)
#    Vehicle 912: Lost at frame 6041, found at 6167 (4.2s gap)
#    Vehicle 912: Lost at frame 6192, found at 6275 (2.8s gap)
#    Vehicle 912: Lost at frame 6296, found at 6315 (0.6s gap)
#    Vehicle 912: Lost at frame 6344, found at 6348 (0.1s gap)
#    Vehicle 912: Lost at frame 6350, found at 6390 (1.3s gap)
#    Vehicle 912: Lost at frame 6393, found at 6396 (0.1s gap)
#    Vehicle 912: Lost at frame 6398, found at 6399 (0.0s gap)
#    Vehicle 912: Lost at frame 6402, found at 6404 (0.1s gap)
#    Vehicle 912: Lost at frame 6432, found at 6433 (0.0s gap)
#    Vehicle 912: Lost at frame 6434, found at 6435 (0.0s gap)
#    Vehicle 912: Lost at frame 6439, found at 6442 (0.1s gap)
#    Vehicle 912: Lost at frame 6446, found at 6464 (0.6s gap)
#    Vehicle 912: Lost at frame 6468, found at 6472 (0.1s gap)
#    Vehicle 912: Lost at frame 6474, found at 6475 (0.0s gap)
#    Vehicle 912: Lost at frame 6476, found at 6478 (0.1s gap)
#    Vehicle 912: Lost at frame 6584, found at 6585 (0.0s gap)
#    Vehicle 912: Lost at frame 6604, found at 6605 (0.0s gap)
#    Vehicle 912: Lost at frame 6606, found at 6610 (0.1s gap)
#    Vehicle 912: Lost at frame 6612, found at 6613 (0.0s gap)
#    Vehicle 912: Lost at frame 6758, found at 6759 (0.0s gap)
#    Vehicle 912: Lost at frame 6763, found at 6764 (0.0s gap)
#    Vehicle 912: Lost at frame 6769, found at 6775 (0.2s gap)
#    Vehicle 912: Lost at frame 6839, found at 6840 (0.0s gap)
#    Vehicle 912: Lost at frame 6911, found at 6912 (0.0s gap)
#    Vehicle 912: Lost at frame 6935, found at 6938 (0.1s gap)
#    Vehicle 912: Lost at frame 6948, found at 6956 (0.3s gap)
#    Vehicle 912: Lost at frame 6970, found at 6972 (0.1s gap)
#    Vehicle 912: Lost at frame 6980, found at 7005 (0.8s gap)
#    Vehicle 912: Lost at frame 7011, found at 7013 (0.1s gap)
#    Vehicle 912: Lost at frame 7015, found at 7032 (0.6s gap)
#    Vehicle 912: Lost at frame 7056, found at 7057 (0.0s gap)
#    Vehicle 912: Lost at frame 7245, found at 7249 (0.1s gap)
#    Vehicle 912: Lost at frame 7314, found at 7318 (0.1s gap)
#    Vehicle 912: Lost at frame 7325, found at 7326 (0.0s gap)
#    Vehicle 912: Lost at frame 7330, found at 7349 (0.6s gap)
#    Vehicle 912: Lost at frame 7393, found at 7396 (0.1s gap)
#    Vehicle 912: Lost at frame 7398, found at 7400 (0.1s gap)
#    Vehicle 912: Lost at frame 7401, found at 7403 (0.1s gap)
#    Vehicle 912: Lost at frame 7452, found at 7457 (0.2s gap)
#    Vehicle 912: Lost at frame 7458, found at 7567 (3.6s gap)
#    Vehicle 912: Lost at frame 7584, found at 7585 (0.0s gap)
#    Vehicle 912: Lost at frame 7587, found at 7590 (0.1s gap)
#    Vehicle 912: Lost at frame 7614, found at 7616 (0.1s gap)
#    Vehicle 912: Lost at frame 7619, found at 7698 (2.6s gap)
#    Vehicle 912: Lost at frame 7701, found at 7714 (0.4s gap)
#    Vehicle 912: Lost at frame 7736, found at 7738 (0.1s gap)
#    Vehicle 912: Lost at frame 7742, found at 7743 (0.0s gap)
#    Vehicle 912: Lost at frame 7745, found at 7747 (0.1s gap)
#    Vehicle 912: Lost at frame 7748, found at 7751 (0.1s gap)
#    Vehicle 912: Lost at frame 7769, found at 7771 (0.1s gap)
#    Vehicle 912: Lost at frame 7774, found at 7805 (1.0s gap)
#    Vehicle 912: Lost at frame 7807, found at 7808 (0.0s gap)
#    Vehicle 912: Lost at frame 7810, found at 7814 (0.1s gap)
#    Vehicle 912: Lost at frame 7815, found at 7832 (0.6s gap)
#    Vehicle 912: Lost at frame 7834, found at 7891 (1.9s gap)
#    Vehicle 912: Lost at frame 7897, found at 7933 (1.2s gap)
#    Vehicle 912: Lost at frame 8659, found at 8669 (0.3s gap)
#    Vehicle 912: Lost at frame 9379, found at 9382 (0.1s gap)
#    Vehicle 912: Lost at frame 9426, found at 9427 (0.0s gap)
#    Vehicle 912: Lost at frame 9883, found at 9884 (0.0s gap)
#    Vehicle 912: Lost at frame 9885, found at 9886 (0.0s gap)
#    Vehicle 912: Lost at frame 9890, found at 9893 (0.1s gap)
#    Vehicle 912: Lost at frame 10037, found at 10038 (0.0s gap)
#    Vehicle 912: Lost at frame 10054, found at 10056 (0.1s gap)
#    Vehicle 912: Lost at frame 10082, found at 10090 (0.3s gap)
#    Vehicle 912: Lost at frame 10095, found at 10097 (0.1s gap)
#    Vehicle 912: Lost at frame 10458, found at 10459 (0.0s gap)
#    Vehicle 912: Lost at frame 10465, found at 10466 (0.0s gap)
#    Vehicle 912: Lost at frame 10791, found at 10792 (0.0s gap)
#    Vehicle 912: Lost at frame 11277, found at 11278 (0.0s gap)
#    Vehicle 912: Lost at frame 11280, found at 11282 (0.1s gap)
