# %% [markdown]
# # Parking Detection Experiments
#
# ## Quick Start:
# 1. Set model path and video path
# 2. Run cells
# 3. Results saved automatically to `../output/experiments/`

# %%
import cv2
import numpy as np
from ultralytics import YOLO
import json
import os
import time
import pandas as pd
from datetime import datetime
from collections import defaultdict

class ParkingDetector:
    def __init__(self, model_path, video_path):
        self.model_path = model_path
        self.video_path = video_path
        self.model_name = os.path.splitext(os.path.basename(model_path))[0]
        self.video_name = os.path.splitext(os.path.basename(video_path))[0]
        
        # Find parking areas file
        self.areas_file = f'../output/parking-areas-{self.video_name}.json'
        
        # Results
        self.results = {
            'experiment_id': f"{self.model_name}_{self.video_name}_{datetime.now().strftime('%Y%m%d_%H%M%S')}",
            'model_path': model_path,
            'video_path': video_path,
            'areas_file': self.areas_file,
            'fps_data': [],
            'parked_vehicles': [],
            'tracking_issues': [],  # New: track flickering/lost detections
            'detection_stats': {},
            'performance': {}
        }
        
        print(f"Model: {self.model_name}")
        print(f"Video: {self.video_name}")
        print(f"Looking for areas: {self.areas_file}")
        
    def load_model_and_areas(self):
        # Load YOLO model
        print("\nLoading model...")
        self.model = YOLO(self.model_path)
        print(f"Model loaded: {self.model_name}")
        
        # Load parking areas
        if not os.path.exists(self.areas_file):
            print(f"Parking areas not found: {self.areas_file}")
            print("   Run define-park-areas.ipynb first!")
            return False
            
        with open(self.areas_file, 'r') as f:
            areas_data = json.load(f)
            
        self.parking_areas = [np.array(area) for area in areas_data['parking_areas']]
        print(f"Loaded {len(self.parking_areas)} parking areas")
        return True
        
    def is_in_parking_area(self, center_point):
        for i, area in enumerate(self.parking_areas):
            if cv2.pointPolygonTest(area, center_point, False) >= 0:
                return i
        return -1
        
    def run_detection(self, show_video=True):
        if not self.load_model_and_areas():
            return False
            
        print("\nStarting detection...")
        
        cap = cv2.VideoCapture(self.video_path)
        if not cap.isOpened():
            print(f"Cannot open video: {self.video_path}")
            return False
            
        # Video properties
        fps = cap.get(cv2.CAP_PROP_FPS)
        total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        
        # Tracking
        parking_timers = defaultdict(lambda: None)
        parked_vehicles = set()
        vehicle_classes = [2, 3, 5, 7]  # car, motorcycle, bus, truck
        parking_threshold = 30  # seconds
        
        # Flickering/tracking issue detection
        last_seen = {}  # track_id -> frame_count when last seen
        lost_vehicles = {}  # track_id -> frame_count when lost
        tracking_gaps = defaultdict(list)  # track_id -> list of (lost_frame, found_frame) gaps
        
        # Stats
        frame_count = 0
        total_detections = 0
        start_time = time.time()
        fps_times = []
        
        print(f"Video: {total_frames} frames, {fps:.1f} FPS")
        if show_video:
            print("Press 'q' to stop early, 's' to toggle video display")
        else:
            print("Processing without video display (faster)")
        print()
        
        display_video = show_video
        
        while True:
            frame_start = time.time()
            
            ret, frame = cap.read()
            if not ret:
                break
                
            frame_count += 1
            current_time = frame_count / fps
            
            # Run detection
            results = self.model.track(frame, persist=True, classes=vehicle_classes, verbose=False)
            
            # Draw parking areas on frame
            if display_video:
                display_frame = frame.copy()
                for i, area in enumerate(self.parking_areas):
                    cv2.polylines(display_frame, [area], True, (0, 255, 0), 2)
                    # Add area label
                    center = area.mean(axis=0).astype(int)
                    cv2.putText(display_frame, f"Area {i+1}", tuple(center), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
            
            # Process detections
            current_frame_vehicles = set()
            if results[0].boxes is not None and results[0].boxes.id is not None:
                boxes = results[0].boxes.xywh.cpu()
                track_ids = results[0].boxes.id.int().cpu().tolist()
                confidences = results[0].boxes.conf.float().cpu().tolist()
                
                for box, track_id, conf in zip(boxes, track_ids, confidences):
                    if conf < 0.5:
                        continue
                        
                    total_detections += 1
                    current_frame_vehicles.add(track_id)
                    
                    # Track flickering: check if this vehicle was lost and now found
                    if track_id in lost_vehicles:
                        lost_frame = lost_vehicles[track_id]
                        gap_duration = frame_count - lost_frame
                        tracking_gaps[track_id].append({
                            'lost_frame': lost_frame,
                            'found_frame': frame_count,
                            'gap_duration': gap_duration,
                            'gap_time_seconds': gap_duration / fps
                        })
                        print(f"Vehicle {track_id} re-tracked after {gap_duration} frames ({gap_duration/fps:.1f}s)")
                        del lost_vehicles[track_id]
                    
                    # Update last seen
                    last_seen[track_id] = frame_count
                    
                    # Get vehicle center and bounding box
                    x, y, w, h = box
                    center = (int(x), int(y))
                    
                    # Draw detection on frame
                    if display_video:
                        x1, y1 = int(x - w/2), int(y - h/2)
                        x2, y2 = int(x + w/2), int(y + h/2)
                        
                        # Check if in parking area
                        area_id = self.is_in_parking_area(center)
                        
                        if area_id >= 0:  # In parking area
                            # Check if vehicle is already marked as parked
                            if track_id in parked_vehicles:
                                color = (0, 0, 255)  # Red for parked vehicles
                                label = f"ID:{track_id} PARKED Area:{area_id+1}"
                            else:
                                color = (0, 255, 255)  # Yellow for vehicles in parking area but not yet parked
                                label = f"ID:{track_id} Area:{area_id+1}"
                        else:
                            color = (255, 0, 0)  # Blue for other vehicles
                            label = f"ID:{track_id}"
                            
                        cv2.rectangle(display_frame, (x1, y1), (x2, y2), color, 2)
                        cv2.putText(display_frame, label, (x1, y1-10), 
                                   cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)
                    
                    # Check if in parking area
                    area_id = self.is_in_parking_area(center)
                    
                    if area_id >= 0:  # In parking area
                        if track_id not in parking_timers:
                            parking_timers[track_id] = current_time
                            
                        # Check if parked long enough
                        parked_duration = current_time - parking_timers[track_id]
                        
                        if parked_duration >= parking_threshold and track_id not in parked_vehicles:
                            parked_vehicles.add(track_id)
                            
                            # Save parked vehicle data
                            self.results['parked_vehicles'].append({
                                'track_id': track_id,
                                'area_id': area_id + 1,
                                'time': current_time,
                                'frame': frame_count,
                                'duration': parked_duration
                            })
                            print(f"Vehicle {track_id} parked in area {area_id+1} after {parked_duration:.1f}s")
                    else:
                        # Vehicle left parking area
                        if track_id in parking_timers:
                            del parking_timers[track_id]
                        if track_id in parked_vehicles:
                            parked_vehicles.remove(track_id)
            
            # Detect lost vehicles (were seen recently but not in current frame)
            for vehicle_id, last_frame in list(last_seen.items()):
                if vehicle_id not in current_frame_vehicles and (frame_count - last_frame) == 1:
                    # Vehicle just lost tracking
                    lost_vehicles[vehicle_id] = frame_count
                    print(f"Vehicle {vehicle_id} lost tracking at frame {frame_count}")
            
            # Display video frame
            if display_video:
                # Add info overlay
                info_text = [
                    f"Frame: {frame_count}/{total_frames}",
                    f"FPS: {processing_fps:.1f}" if 'processing_fps' in locals() else "FPS: calculating...",
                    f"Detections: {total_detections}",
                    f"Parked: {len(parked_vehicles)}"
                ]
                
                for i, text in enumerate(info_text):
                    cv2.putText(display_frame, text, (10, 30 + i*25), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)
                
                cv2.imshow('Parking Detection', display_frame)
            
            # Calculate FPS
            frame_time = time.time() - frame_start
            processing_fps = 1.0 / frame_time if frame_time > 0 else 0
            fps_times.append(processing_fps)
            
            # Show progress
            if frame_count % 30 == 0:
                progress = (frame_count / total_frames) * 100
                avg_fps = sum(fps_times[-30:]) / min(30, len(fps_times))
                print(f"Progress: {progress:.1f}% | FPS: {avg_fps:.1f} | Parked: {len(parked_vehicles)}")
            
            # Check for quit or display toggle
            key = cv2.waitKey(1) & 0xFF
            if key == ord('q'):
                print("Stopped by user")
                break
            elif key == ord('s'):
                display_video = not display_video
                if display_video:
                    print("Video display enabled")
                else:
                    print("Video display disabled")
                    cv2.destroyAllWindows()
                
        cap.release()
        cv2.destroyAllWindows()
        
        # Calculate final stats
        total_time = time.time() - start_time
        avg_fps = sum(fps_times) / len(fps_times) if fps_times else 0
        
        # Process tracking issues data
        total_gaps = sum(len(gaps) for gaps in tracking_gaps.values())
        vehicles_with_gaps = len(tracking_gaps)
        
        # Convert tracking gaps to list format for JSON serialization
        tracking_issues_list = []
        for vehicle_id, gaps in tracking_gaps.items():
            for gap in gaps:
                tracking_issues_list.append({
                    'track_id': vehicle_id,
                    'lost_frame': gap['lost_frame'],
                    'found_frame': gap['found_frame'],
                    'gap_duration_frames': gap['gap_duration'],
                    'gap_duration_seconds': gap['gap_time_seconds']
                })
        
        self.results['fps_data'] = fps_times
        self.results['tracking_issues'] = tracking_issues_list
        self.results['detection_stats'] = {
            'total_frames': frame_count,
            'total_detections': total_detections,
            'unique_parked': len(parked_vehicles),
            'processing_time': total_time,
            'tracking_gaps_total': total_gaps,
            'vehicles_with_tracking_issues': vehicles_with_gaps
        }
        self.results['performance'] = {
            'avg_fps': avg_fps,
            'min_fps': min(fps_times) if fps_times else 0,
            'max_fps': max(fps_times) if fps_times else 0
        }
        
        print(f"\nDetection completed!")
        print(f"Processed {frame_count} frames in {total_time:.1f}s")
        print(f"Average FPS: {avg_fps:.1f}")
        print(f"Parked vehicles detected: {len(parked_vehicles)}")
        print(f"Tracking issues: {total_gaps} gaps in {vehicles_with_gaps} vehicles")
        
        return True
        
    def save_results(self):
        # Create output directory
        output_dir = f"../output/experiments/{self.results['experiment_id']}"
        os.makedirs(output_dir, exist_ok=True)
        
        # Save JSON results
        json_file = f"{output_dir}/results.json"
        with open(json_file, 'w') as f:
            json.dump(self.results, f, indent=2, default=str)
            
        # Save CSV summary
        csv_file = f"{output_dir}/summary.csv"
        summary_data = {
            'experiment_id': [self.results['experiment_id']],
            'model': [self.model_name],
            'video': [self.video_name],
            'avg_fps': [self.results['performance']['avg_fps']],
            'min_fps': [self.results['performance']['min_fps']],
            'max_fps': [self.results['performance']['max_fps']],
            'total_frames': [self.results['detection_stats']['total_frames']],
            'total_detections': [self.results['detection_stats']['total_detections']],
            'parked_vehicles': [self.results['detection_stats']['unique_parked']],
            'processing_time': [self.results['detection_stats']['processing_time']],
            'tracking_gaps': [self.results['detection_stats']['tracking_gaps_total']],
            'vehicles_with_issues': [self.results['detection_stats']['vehicles_with_tracking_issues']]
        }
        
        df = pd.DataFrame(summary_data)
        df.to_csv(csv_file, index=False)
        
        # Save parked vehicles details
        if self.results['parked_vehicles']:
            parked_df = pd.DataFrame(self.results['parked_vehicles'])
            parked_df.to_csv(f"{output_dir}/parked_vehicles.csv", index=False)
            
        # Save tracking issues details
        if self.results['tracking_issues']:
            tracking_df = pd.DataFrame(self.results['tracking_issues'])
            tracking_df.to_csv(f"{output_dir}/tracking_issues.csv", index=False)
            
        print(f"\nResults saved to: {output_dir}")
        files_list = "results.json, summary.csv"
        if self.results['parked_vehicles']:
            files_list += ", parked_vehicles.csv"
        if self.results['tracking_issues']:
            files_list += ", tracking_issues.csv"
        print(f"Files: {files_list}")
        
        return output_dir
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/Users/sistemcerdasfive/Library/Application Support/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# EXPERIMENT CONFIGURATION

# Model and dataset paths
model_path = '../yolo-model/yolov8n.pt'
video_path = '../dataset/video_1_cut50-00_01-00-00.mov'

print(f"Configuration:")
print(f"   Model: {model_path}")
print(f"   Video: {video_path}")

# Check files exist
if not os.path.exists(model_path):
    print(f"Model not found: {model_path}")
elif not os.path.exists(video_path):
    print(f"Video not found: {video_path}")
else:
    print(f"Files found, ready to run!")
# Out:
# Configuration:
#    Model: ../yolo-model/yolov8n.pt
#    Video: ../dataset/video_1_cut50-00_01-00-00.mov
# Model not found: ../yolo-model/yolov8n.pt

# %%
# RUN DETECTION EXPERIMENT

detector = ParkingDetector(model_path, video_path)

if detector.run_detection(show_video=True):  # Set to False for faster processing without video
    output_dir = detector.save_results()
    print(f"\nExperiment completed successfully!")
    print(f"Check results in: {output_dir}")
else:
    print(f"\nExperiment failed")
    print(f"   Make sure you've run define-park-areas.ipynb first")
# Out:
# Model: yolov8n
# Video: video_1_cut50-00_01-00-00
# Looking for areas: ../output/parking-areas-video_1_cut50-00_01-00-00.json
#
# Loading model...
# WARNING ⚠️ Download failure, retrying 1/3 https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt...
# ######################################################################## 100.0%
# Model loaded: yolov8n
# Loaded 2 parking areas
#
# Starting detection...
# Video: 18000 frames, 30.0 FPS
# Press 'q' to stop early, 's' to toggle video display
#
# Vehicle 5 lost tracking at frame 2
# Vehicle 6 lost tracking at frame 2
# Vehicle 7 lost tracking at frame 2
# Vehicle 7 re-tracked after 2 frames (0.1s)
# Vehicle 11 lost tracking at frame 4
# Vehicle 12 lost tracking at frame 4
# Vehicle 11 re-tracked after 2 frames (0.1s)
# Vehicle 6 re-tracked after 5 frames (0.2s)
# Vehicle 12 re-tracked after 3 frames (0.1s)
# Vehicle 7 lost tracking at frame 7
# Vehicle 6 lost tracking at frame 8
# Vehicle 14 lost tracking at frame 8
# Vehicle 2 lost tracking at frame 12
# Vehicle 2 re-tracked after 2 frames (0.1s)
# Vehicle 12 lost tracking at frame 14
# Vehicle 7 re-tracked after 12 frames (0.4s)
# Vehicle 8 lost tracking at frame 19
# Vehicle 7 lost tracking at frame 20
# Vehicle 18 lost tracking at frame 20
# Vehicle 7 re-tracked after 4 frames (0.1s)
# Vehicle 2 lost tracking at frame 24
# Vehicle 2 re-tracked after 2 frames (0.1s)
# Vehicle 7 lost tracking at frame 26
# Vehicle 7 re-tracked after 1 frames (0.0s)
# Vehicle 2 lost tracking at frame 27
# Vehicle 4 lost tracking at frame 27
# Vehicle 25 lost tracking at frame 27
# Vehicle 2 re-tracked after 1 frames (0.0s)
# Vehicle 4 re-tracked after 1 frames (0.0s)
# Vehicle 7 lost tracking at frame 28
# Vehicle 23 lost tracking at frame 28
# Vehicle 2 lost tracking at frame 30
# Progress: 0.2% | FPS: 18.3 | Parked: 0
# Vehicle 6 re-tracked after 23 frames (0.8s)
# Vehicle 7 re-tracked after 3 frames (0.1s)
# Vehicle 1 lost tracking at frame 31
# Vehicle 4 lost tracking at frame 31
# Vehicle 2 re-tracked after 2 frames (0.1s)
# Vehicle 4 re-tracked after 1 frames (0.0s)
# Vehicle 23 re-tracked after 4 frames (0.1s)
# Vehicle 12 re-tracked after 18 frames (0.6s)
# Vehicle 6 lost tracking at frame 32
# Vehicle 7 lost tracking at frame 32
# Vehicle 29 lost tracking at frame 32
# Vehicle 2 lost tracking at frame 34
# Vehicle 12 lost tracking at frame 34
# Vehicle 8 re-tracked after 16 frames (0.5s)
# Vehicle 18 re-tracked after 15 frames (0.5s)
# Vehicle 4 lost tracking at frame 37
# Vehicle 18 lost tracking at frame 37
# Vehicle 2 re-tracked after 4 frames (0.1s)
# Vehicle 7 re-tracked after 7 frames (0.2s)
# Vehicle 8 lost tracking at frame 39
# Vehicle 4 re-tracked after 4 frames (0.1s)
# Vehicle 7 lost tracking at frame 41
# Vehicle 23 lost tracking at frame 41
# Vehicle 8 re-tracked after 3 frames (0.1s)
# Vehicle 2 lost tracking at frame 42
# Vehicle 7 re-tracked after 2 frames (0.1s)
# Vehicle 25 re-tracked after 16 frames (0.5s)
# Vehicle 2 re-tracked after 2 frames (0.1s)
# Vehicle 7 lost tracking at frame 46
# Vehicle 25 lost tracking at frame 46
# Vehicle 2 lost tracking at frame 47
# Vehicle 9 lost tracking at frame 47
# Vehicle 9 re-tracked after 1 frames (0.0s)
# Vehicle 18 re-tracked after 11 frames (0.4s)
# Vehicle 9 lost tracking at frame 49
# Vehicle 18 lost tracking at frame 52
# Vehicle 2 re-tracked after 7 frames (0.2s)
# Vehicle 2 lost tracking at frame 56
# Vehicle 18 re-tracked after 6 frames (0.2s)
# Vehicle 2 re-tracked after 3 frames (0.1s)
# Vehicle 18 lost tracking at frame 59
# Progress: 0.3% | FPS: 20.1 | Parked: 0
# Vehicle 2 lost tracking at frame 61
# Vehicle 49 lost tracking at frame 62
# Vehicle 18 re-tracked after 9 frames (0.3s)
# Vehicle 18 lost tracking at frame 71
# Vehicle 2 re-tracked after 11 frames (0.4s)
# Vehicle 18 re-tracked after 1 frames (0.0s)
# Vehicle 18 lost tracking at frame 74
# Vehicle 13 lost tracking at frame 74
# Vehicle 2 lost tracking at frame 76
# Vehicle 2 re-tracked after 4 frames (0.1s)
# Vehicle 2 lost tracking at frame 83
# Vehicle 9 re-tracked after 37 frames (1.2s)
# Vehicle 9 lost tracking at frame 87
# Vehicle 9 re-tracked after 1 frames (0.0s)
# Vehicle 49 re-tracked after 26 frames (0.9s)
# Vehicle 49 lost tracking at frame 90
# Progress: 0.5% | FPS: 20.2 | Parked: 0
# Vehicle 49 re-tracked after 8 frames (0.3s)
# Vehicle 9 lost tracking at frame 98
# Vehicle 9 re-tracked after 1 frames (0.0s)
# Vehicle 9 lost tracking at frame 103
# Vehicle 49 lost tracking at frame 104
# Vehicle 69 lost tracking at frame 106
# Vehicle 69 re-tracked after 1 frames (0.0s)
# Vehicle 49 re-tracked after 6 frames (0.2s)
# Vehicle 49 lost tracking at frame 111
# Vehicle 69 lost tracking at frame 118
# Progress: 0.7% | FPS: 20.2 | Parked: 0
# Vehicle 69 re-tracked after 5 frames (0.2s)
# Vehicle 13 re-tracked after 50 frames (1.7s)
# Vehicle 69 lost tracking at frame 127
# Vehicle 69 re-tracked after 3 frames (0.1s)
# Vehicle 3 lost tracking at frame 132
# Vehicle 9 re-tracked after 30 frames (1.0s)
# Vehicle 13 lost tracking at frame 133
# Vehicle 84 lost tracking at frame 133
# Vehicle 3 re-tracked after 2 frames (0.1s)
# Vehicle 13 re-tracked after 1 frames (0.0s)
# Vehicle 69 lost tracking at frame 134
# Vehicle 69 re-tracked after 1 frames (0.0s)
# Vehicle 3 lost tracking at frame 135
# Vehicle 13 lost tracking at frame 135
# Vehicle 13 re-tracked after 1 frames (0.0s)
# Vehicle 84 re-tracked after 3 frames (0.1s)
# Vehicle 84 lost tracking at frame 138
# Vehicle 84 re-tracked after 1 frames (0.0s)
# Vehicle 13 lost tracking at frame 140
# Vehicle 13 re-tracked after 1 frames (0.0s)
# Vehicle 13 lost tracking at frame 143
# Vehicle 13 re-tracked after 3 frames (0.1s)
# Vehicle 69 lost tracking at frame 149
# Vehicle 69 re-tracked after 1 frames (0.0s)
# Progress: 0.8% | FPS: 20.3 | Parked: 0
# Vehicle 84 lost tracking at frame 156
# Vehicle 3 re-tracked after 23 frames (0.8s)
# Vehicle 84 re-tracked after 2 frames (0.1s)
# Vehicle 3 lost tracking at frame 159
# Vehicle 69 lost tracking at frame 161
# Vehicle 84 lost tracking at frame 162
# Vehicle 3 re-tracked after 4 frames (0.1s)
# Vehicle 8 lost tracking at frame 166
# Vehicle 8 re-tracked after 1 frames (0.0s)
# Vehicle 69 re-tracked after 7 frames (0.2s)
# Vehicle 3 lost tracking at frame 168
# Vehicle 8 lost tracking at frame 168
# Vehicle 69 lost tracking at frame 171
# Vehicle 3 re-tracked after 6 frames (0.2s)
# Vehicle 8 re-tracked after 6 frames (0.2s)
# Vehicle 8 lost tracking at frame 175
# Vehicle 3 lost tracking at frame 176
# Vehicle 13 lost tracking at frame 176
# Vehicle 3 re-tracked after 2 frames (0.1s)
# Vehicle 8 re-tracked after 3 frames (0.1s)
# Vehicle 69 re-tracked after 7 frames (0.2s)
# Vehicle 3 lost tracking at frame 179
# Vehicle 8 lost tracking at frame 179
# Vehicle 69 lost tracking at frame 179
# Progress: 1.0% | FPS: 20.1 | Parked: 0
# Vehicle 69 re-tracked after 4 frames (0.1s)
# Vehicle 104 lost tracking at frame 183
# Vehicle 106 lost tracking at frame 186
# Vehicle 4 lost tracking at frame 187
# Vehicle 4 re-tracked after 1 frames (0.0s)
# Vehicle 99 lost tracking at frame 188
# Vehicle 3 re-tracked after 11 frames (0.4s)
# Vehicle 4 lost tracking at frame 190
# Vehicle 4 re-tracked after 1 frames (0.0s)
# Vehicle 99 re-tracked after 3 frames (0.1s)
# Vehicle 8 re-tracked after 13 frames (0.4s)
# Vehicle 4 lost tracking at frame 193
# Vehicle 8 lost tracking at frame 193
# Vehicle 99 lost tracking at frame 193
# Vehicle 99 re-tracked after 3 frames (0.1s)
# Vehicle 69 lost tracking at frame 198
# Vehicle 99 lost tracking at frame 198
# Vehicle 99 re-tracked after 1 frames (0.0s)
# Vehicle 69 re-tracked after 2 frames (0.1s)
# Vehicle 111 lost tracking at frame 200
# Vehicle 111 re-tracked after 1 frames (0.0s)
# Vehicle 69 lost tracking at frame 202
# Vehicle 69 re-tracked after 1 frames (0.0s)
# Vehicle 99 lost tracking at frame 203
# Vehicle 99 re-tracked after 1 frames (0.0s)
# Vehicle 99 lost tracking at frame 205
# Vehicle 99 re-tracked after 3 frames (0.1s)
# Vehicle 111 lost tracking at frame 209
# Vehicle 111 re-tracked after 1 frames (0.0s)
# Progress: 1.2% | FPS: 20.0 | Parked: 0
# Vehicle 111 lost tracking at frame 211
# Vehicle 8 re-tracked after 19 frames (0.6s)
# Vehicle 8 lost tracking at frame 213
# Vehicle 8 re-tracked after 2 frames (0.1s)
# Vehicle 8 lost tracking at frame 219
# Vehicle 8 re-tracked after 1 frames (0.0s)
# Vehicle 69 lost tracking at frame 221
# Vehicle 69 re-tracked after 1 frames (0.0s)
# Vehicle 136 lost tracking at frame 222
# Vehicle 99 lost tracking at frame 228
# Vehicle 99 re-tracked after 1 frames (0.0s)
# Vehicle 13 re-tracked after 56 frames (1.9s)
# Vehicle 13 lost tracking at frame 233
# Vehicle 13 re-tracked after 1 frames (0.0s)
# Vehicle 99 lost tracking at frame 234
# Vehicle 13 lost tracking at frame 235
# Vehicle 13 re-tracked after 1 frames (0.0s)
# Progress: 1.3% | FPS: 19.9 | Parked: 0
# Vehicle 99 re-tracked after 7 frames (0.2s)
# Vehicle 99 lost tracking at frame 243
# 2025-10-01 23:32:46.264 Python[33432:572961] WARNING: Secure coding is not enabled for restorable state! Enable secure coding by implementing NSApplicationDelegate.applicationSupportsSecureRestorableState: and returning YES.
# Vehicle 13 lost tracking at frame 244
# Vehicle 158 lost tracking at frame 246
# Vehicle 158 re-tracked after 2 frames (0.1s)
# Vehicle 158 lost tracking at frame 249
# Vehicle 13 re-tracked after 9 frames (0.3s)
# Vehicle 13 lost tracking at frame 255
# Vehicle 109 lost tracking at frame 256
# Vehicle 109 re-tracked after 1 frames (0.0s)
# Vehicle 9 lost tracking at frame 259
# Vehicle 178 lost tracking at frame 261
# Vehicle 109 lost tracking at frame 268
# Vehicle 183 lost tracking at frame 268
# Vehicle 109 re-tracked after 1 frames (0.0s)
# Vehicle 183 re-tracked after 1 frames (0.0s)
# Vehicle 109 lost tracking at frame 270
# Vehicle 183 lost tracking at frame 270
# Progress: 1.5% | FPS: 19.9 | Parked: 0
# Vehicle 13 re-tracked after 16 frames (0.5s)
# Vehicle 109 re-tracked after 1 frames (0.0s)
# Vehicle 13 lost tracking at frame 272
# Vehicle 3 lost tracking at frame 276
# Vehicle 3 re-tracked after 1 frames (0.0s)
# Vehicle 147 lost tracking at frame 278
# Vehicle 147 re-tracked after 1 frames (0.0s)
# Vehicle 183 re-tracked after 10 frames (0.3s)
# Vehicle 147 lost tracking at frame 280
# Vehicle 109 lost tracking at frame 282
# Vehicle 13 re-tracked after 11 frames (0.4s)
# Vehicle 109 re-tracked after 2 frames (0.1s)
# Vehicle 183 lost tracking at frame 286
# Vehicle 183 re-tracked after 1 frames (0.0s)
# Vehicle 109 lost tracking at frame 287
# Vehicle 109 re-tracked after 1 frames (0.0s)
# Vehicle 183 lost tracking at frame 288
# Vehicle 205 lost tracking at frame 292
# Vehicle 175 lost tracking at frame 292
# Vehicle 213 lost tracking at frame 292
# Vehicle 175 re-tracked after 1 frames (0.0s)
# Vehicle 175 lost tracking at frame 294
# Vehicle 205 re-tracked after 3 frames (0.1s)
# Vehicle 213 re-tracked after 3 frames (0.1s)
# Vehicle 13 lost tracking at frame 295
# Vehicle 175 re-tracked after 2 frames (0.1s)
# Vehicle 205 lost tracking at frame 296
# Vehicle 205 re-tracked after 2 frames (0.1s)
# Vehicle 213 lost tracking at frame 300
# Progress: 1.7% | FPS: 19.9 | Parked: 0
# Vehicle 213 re-tracked after 1 frames (0.0s)
# Vehicle 13 re-tracked after 7 frames (0.2s)
# Vehicle 213 lost tracking at frame 303
# Vehicle 13 lost tracking at frame 304
# Vehicle 213 re-tracked after 3 frames (0.1s)
# Vehicle 13 re-tracked after 3 frames (0.1s)
# Vehicle 13 lost tracking at frame 308
# Vehicle 3 lost tracking at frame 319
# Vehicle 3 re-tracked after 1 frames (0.0s)
# Vehicle 213 lost tracking at frame 320
# Vehicle 3 lost tracking at frame 322
# Vehicle 213 re-tracked after 3 frames (0.1s)
# Vehicle 227 lost tracking at frame 330
# Vehicle 241 lost tracking at frame 330
# Progress: 1.8% | FPS: 19.9 | Parked: 0
# Vehicle 241 re-tracked after 4 frames (0.1s)
# Vehicle 241 lost tracking at frame 335
# Vehicle 13 re-tracked after 29 frames (1.0s)
# Vehicle 213 lost tracking at frame 337
# Vehicle 213 re-tracked after 1 frames (0.0s)
# Vehicle 109 lost tracking at frame 338
# Vehicle 241 re-tracked after 4 frames (0.1s)
# Vehicle 109 re-tracked after 2 frames (0.1s)
# Vehicle 241 lost tracking at frame 340
# Vehicle 109 lost tracking at frame 342
# Vehicle 13 lost tracking at frame 343
# Vehicle 241 re-tracked after 4 frames (0.1s)
# Vehicle 215 lost tracking at frame 344
# Vehicle 13 re-tracked after 2 frames (0.1s)
# Vehicle 175 lost tracking at frame 347
# Vehicle 213 lost tracking at frame 347
# Vehicle 213 re-tracked after 1 frames (0.0s)
# Vehicle 175 re-tracked after 3 frames (0.1s)
# Vehicle 13 lost tracking at frame 350
# Vehicle 13 re-tracked after 1 frames (0.0s)
# Vehicle 241 lost tracking at frame 351
# Vehicle 215 re-tracked after 9 frames (0.3s)
# Vehicle 3 re-tracked after 31 frames (1.0s)
# Vehicle 3 lost tracking at frame 354
# Vehicle 213 lost tracking at frame 354
# Vehicle 213 re-tracked after 1 frames (0.0s)
# Vehicle 69 lost tracking at frame 355
# Vehicle 3 re-tracked after 2 frames (0.1s)
# Vehicle 213 lost tracking at frame 356
# Vehicle 205 lost tracking at frame 358
# Vehicle 205 re-tracked after 1 frames (0.0s)
# Vehicle 215 lost tracking at frame 359
# Vehicle 213 re-tracked after 4 frames (0.1s)
# Vehicle 215 re-tracked after 1 frames (0.0s)
# Progress: 2.0% | FPS: 19.8 | Parked: 0
# Vehicle 215 lost tracking at frame 361
# Vehicle 215 re-tracked after 1 frames (0.0s)
# Vehicle 205 lost tracking at frame 363
# Vehicle 213 lost tracking at frame 363
# Vehicle 213 re-tracked after 2 frames (0.1s)
# Vehicle 213 lost tracking at frame 368
# Vehicle 213 re-tracked after 3 frames (0.1s)
# Vehicle 213 lost tracking at frame 376
# Vehicle 213 re-tracked after 1 frames (0.0s)
# Vehicle 285 lost tracking at frame 390
# Progress: 2.2% | FPS: 20.2 | Parked: 0
# Vehicle 285 re-tracked after 1 frames (0.0s)
# Vehicle 213 lost tracking at frame 392
# Vehicle 285 lost tracking at frame 392
# Vehicle 213 re-tracked after 2 frames (0.1s)
# Vehicle 3 lost tracking at frame 395
# Vehicle 213 lost tracking at frame 395
# Vehicle 213 re-tracked after 2 frames (0.1s)
# Vehicle 3 re-tracked after 2 frames (0.1s)
# Vehicle 213 lost tracking at frame 398
# Vehicle 3 lost tracking at frame 399
# Vehicle 3 re-tracked after 2 frames (0.1s)
# Vehicle 3 lost tracking at frame 404
# Vehicle 3 re-tracked after 6 frames (0.2s)
# Vehicle 294 lost tracking at frame 416
# Vehicle 3 lost tracking at frame 418
# Vehicle 3 re-tracked after 1 frames (0.0s)
# Vehicle 297 lost tracking at frame 419
# Vehicle 297 re-tracked after 1 frames (0.0s)
# Progress: 2.3% | FPS: 20.1 | Parked: 0
# Stopped by user
#
# Detection completed!
# Processed 422 frames in 33.4s
# Average FPS: 19.9
# Parked vehicles detected: 0
# Tracking issues: 142 gaps in 29 vehicles
#
# Results saved to: ../output/experiments/yolov8n_video_1_cut50-00_01-00-00_20251001_233223
# Files: results.json, summary.csv, tracking_issues.csv
#
# Experiment completed successfully!
# Check results in: ../output/experiments/yolov8n_video_1_cut50-00_01-00-00_20251001_233223

# %%
# QUICK RESULTS DISPLAY

if 'detector' in locals() and detector.results['detection_stats']:
    print("\nEXPERIMENT RESULTS")
    print("=" * 40)
    
    stats = detector.results['detection_stats']
    perf = detector.results['performance']
    
    print(f"Model: {detector.model_name}")
    print(f"Video: {detector.video_name}")
    print(f"Processing Time: {stats['processing_time']:.1f}s")
    print(f"Frames Processed: {stats['total_frames']}")
    print(f"Average FPS: {perf['avg_fps']:.1f}")
    print(f"Total Detections: {stats['total_detections']}")
    print(f"Parked Vehicles: {stats['unique_parked']}")
    print(f"Tracking Issues: {stats.get('tracking_gaps_total', 0)} gaps in {stats.get('vehicles_with_tracking_issues', 0)} vehicles")
    
    if detector.results['parked_vehicles']:
        print(f"\nParked Vehicle Details:")
        for pv in detector.results['parked_vehicles']:
            print(f"   Vehicle {pv['track_id']}: Area {pv['area_id']}, {pv['duration']:.1f}s")
    
    if detector.results['tracking_issues']:
        print(f"\nTracking Issues Details:")
        for issue in detector.results['tracking_issues']:
            print(f"   Vehicle {issue['track_id']}: Lost at frame {issue['lost_frame']}, found at {issue['found_frame']} ({issue['gap_duration_seconds']:.1f}s gap)")
else:
    print("Run the detection experiment first!")

    #test
# Out:
# EXPERIMENT RESULTS
# ========================================
# Model: yolov8n
# Video: video_1_cut50-00_01-00-00
# Processing Time: 33.4s
# Frames Processed: 422
# Average FPS: 19.9
# Total Detections: 2665
# Parked Vehicles: 0
# Tracking Issues: 142 gaps in 29 vehicles
#
# Tracking Issues Details:
#    Vehicle 7: Lost at frame 2, found at 4 (0.1s gap)
#    Vehicle 7: Lost at frame 7, found at 19 (0.4s gap)
#    Vehicle 7: Lost at frame 20, found at 24 (0.1s gap)
#    Vehicle 7: Lost at frame 26, found at 27 (0.0s gap)
#    Vehicle 7: Lost at frame 28, found at 31 (0.1s gap)
#    Vehicle 7: Lost at frame 32, found at 39 (0.2s gap)
#    Vehicle 7: Lost at frame 41, found at 43 (0.1s gap)
#    Vehicle 11: Lost at frame 4, found at 6 (0.1s gap)
#    Vehicle 6: Lost at frame 2, found at 7 (0.2s gap)
#    Vehicle 6: Lost at frame 8, found at 31 (0.8s gap)
#    Vehicle 12: Lost at frame 4, found at 7 (0.1s gap)
#    Vehicle 12: Lost at frame 14, found at 32 (0.6s gap)
#    Vehicle 2: Lost at frame 12, found at 14 (0.1s gap)
#    Vehicle 2: Lost at frame 24, found at 26 (0.1s gap)
#    Vehicle 2: Lost at frame 27, found at 28 (0.0s gap)
#    Vehicle 2: Lost at frame 30, found at 32 (0.1s gap)
#    Vehicle 2: Lost at frame 34, found at 38 (0.1s gap)
#    Vehicle 2: Lost at frame 42, found at 44 (0.1s gap)
#    Vehicle 2: Lost at frame 47, found at 54 (0.2s gap)
#    Vehicle 2: Lost at frame 56, found at 59 (0.1s gap)
#    Vehicle 2: Lost at frame 61, found at 72 (0.4s gap)
#    Vehicle 2: Lost at frame 76, found at 80 (0.1s gap)
#    Vehicle 4: Lost at frame 27, found at 28 (0.0s gap)
#    Vehicle 4: Lost at frame 31, found at 32 (0.0s gap)
#    Vehicle 4: Lost at frame 37, found at 41 (0.1s gap)
#    Vehicle 4: Lost at frame 187, found at 188 (0.0s gap)
#    Vehicle 4: Lost at frame 190, found at 191 (0.0s gap)
#    Vehicle 23: Lost at frame 28, found at 32 (0.1s gap)
#    Vehicle 8: Lost at frame 19, found at 35 (0.5s gap)
#    Vehicle 8: Lost at frame 39, found at 42 (0.1s gap)
#    Vehicle 8: Lost at frame 166, found at 167 (0.0s gap)
#    Vehicle 8: Lost at frame 168, found at 174 (0.2s gap)
#    Vehicle 8: Lost at frame 175, found at 178 (0.1s gap)
#    Vehicle 8: Lost at frame 179, found at 192 (0.4s gap)
#    Vehicle 8: Lost at frame 193, found at 212 (0.6s gap)
#    Vehicle 8: Lost at frame 213, found at 215 (0.1s gap)
#    Vehicle 8: Lost at frame 219, found at 220 (0.0s gap)
#    Vehicle 18: Lost at frame 20, found at 35 (0.5s gap)
#    Vehicle 18: Lost at frame 37, found at 48 (0.4s gap)
#    Vehicle 18: Lost at frame 52, found at 58 (0.2s gap)
#    Vehicle 18: Lost at frame 59, found at 68 (0.3s gap)
#    Vehicle 18: Lost at frame 71, found at 72 (0.0s gap)
#    Vehicle 25: Lost at frame 27, found at 43 (0.5s gap)
#    Vehicle 9: Lost at frame 47, found at 48 (0.0s gap)
#    Vehicle 9: Lost at frame 49, found at 86 (1.2s gap)
#    Vehicle 9: Lost at frame 87, found at 88 (0.0s gap)
#    Vehicle 9: Lost at frame 98, found at 99 (0.0s gap)
#    Vehicle 9: Lost at frame 103, found at 133 (1.0s gap)
#    Vehicle 49: Lost at frame 62, found at 88 (0.9s gap)
#    Vehicle 49: Lost at frame 90, found at 98 (0.3s gap)
#    Vehicle 49: Lost at frame 104, found at 110 (0.2s gap)
#    Vehicle 69: Lost at frame 106, found at 107 (0.0s gap)
#    Vehicle 69: Lost at frame 118, found at 123 (0.2s gap)
#    Vehicle 69: Lost at frame 127, found at 130 (0.1s gap)
#    Vehicle 69: Lost at frame 134, found at 135 (0.0s gap)
#    Vehicle 69: Lost at frame 149, found at 150 (0.0s gap)
#    Vehicle 69: Lost at frame 161, found at 168 (0.2s gap)
#    Vehicle 69: Lost at frame 171, found at 178 (0.2s gap)
#    Vehicle 69: Lost at frame 179, found at 183 (0.1s gap)
#    Vehicle 69: Lost at frame 198, found at 200 (0.1s gap)
#    Vehicle 69: Lost at frame 202, found at 203 (0.0s gap)
#    Vehicle 69: Lost at frame 221, found at 222 (0.0s gap)
#    Vehicle 13: Lost at frame 74, found at 124 (1.7s gap)
#    Vehicle 13: Lost at frame 133, found at 134 (0.0s gap)
#    Vehicle 13: Lost at frame 135, found at 136 (0.0s gap)
#    Vehicle 13: Lost at frame 140, found at 141 (0.0s gap)
#    Vehicle 13: Lost at frame 143, found at 146 (0.1s gap)
#    Vehicle 13: Lost at frame 176, found at 232 (1.9s gap)
#    Vehicle 13: Lost at frame 233, found at 234 (0.0s gap)
#    Vehicle 13: Lost at frame 235, found at 236 (0.0s gap)
#    Vehicle 13: Lost at frame 244, found at 253 (0.3s gap)
#    Vehicle 13: Lost at frame 255, found at 271 (0.5s gap)
#    Vehicle 13: Lost at frame 272, found at 283 (0.4s gap)
#    Vehicle 13: Lost at frame 295, found at 302 (0.2s gap)
#    Vehicle 13: Lost at frame 304, found at 307 (0.1s gap)
#    Vehicle 13: Lost at frame 308, found at 337 (1.0s gap)
#    Vehicle 13: Lost at frame 343, found at 345 (0.1s gap)
#    Vehicle 13: Lost at frame 350, found at 351 (0.0s gap)
#    Vehicle 3: Lost at frame 132, found at 134 (0.1s gap)
#    Vehicle 3: Lost at frame 135, found at 158 (0.8s gap)
#    Vehicle 3: Lost at frame 159, found at 163 (0.1s gap)
#    Vehicle 3: Lost at frame 168, found at 174 (0.2s gap)
#    Vehicle 3: Lost at frame 176, found at 178 (0.1s gap)
#    Vehicle 3: Lost at frame 179, found at 190 (0.4s gap)
#    Vehicle 3: Lost at frame 276, found at 277 (0.0s gap)
#    Vehicle 3: Lost at frame 319, found at 320 (0.0s gap)
#    Vehicle 3: Lost at frame 322, found at 353 (1.0s gap)
#    Vehicle 3: Lost at frame 354, found at 356 (0.1s gap)
#    Vehicle 3: Lost at frame 395, found at 397 (0.1s gap)
#    Vehicle 3: Lost at frame 399, found at 401 (0.1s gap)
#    Vehicle 3: Lost at frame 404, found at 410 (0.2s gap)
#    Vehicle 3: Lost at frame 418, found at 419 (0.0s gap)
#    Vehicle 84: Lost at frame 133, found at 136 (0.1s gap)
#    Vehicle 84: Lost at frame 138, found at 139 (0.0s gap)
#    Vehicle 84: Lost at frame 156, found at 158 (0.1s gap)
#    Vehicle 99: Lost at frame 188, found at 191 (0.1s gap)
#    Vehicle 99: Lost at frame 193, found at 196 (0.1s gap)
#    Vehicle 99: Lost at frame 198, found at 199 (0.0s gap)
#    Vehicle 99: Lost at frame 203, found at 204 (0.0s gap)
#    Vehicle 99: Lost at frame 205, found at 208 (0.1s gap)
#    Vehicle 99: Lost at frame 228, found at 229 (0.0s gap)
#    Vehicle 99: Lost at frame 234, found at 241 (0.2s gap)
#    Vehicle 111: Lost at frame 200, found at 201 (0.0s gap)
#    Vehicle 111: Lost at frame 209, found at 210 (0.0s gap)
#    Vehicle 158: Lost at frame 246, found at 248 (0.1s gap)
#    Vehicle 109: Lost at frame 256, found at 257 (0.0s gap)
#    Vehicle 109: Lost at frame 268, found at 269 (0.0s gap)
#    Vehicle 109: Lost at frame 270, found at 271 (0.0s gap)
#    Vehicle 109: Lost at frame 282, found at 284 (0.1s gap)
#    Vehicle 109: Lost at frame 287, found at 288 (0.0s gap)
#    Vehicle 109: Lost at frame 338, found at 340 (0.1s gap)
#    Vehicle 183: Lost at frame 268, found at 269 (0.0s gap)
#    Vehicle 183: Lost at frame 270, found at 280 (0.3s gap)
#    Vehicle 183: Lost at frame 286, found at 287 (0.0s gap)
#    Vehicle 147: Lost at frame 278, found at 279 (0.0s gap)
#    Vehicle 175: Lost at frame 292, found at 293 (0.0s gap)
#    Vehicle 175: Lost at frame 294, found at 296 (0.1s gap)
#    Vehicle 175: Lost at frame 347, found at 350 (0.1s gap)
#    Vehicle 205: Lost at frame 292, found at 295 (0.1s gap)
#    Vehicle 205: Lost at frame 296, found at 298 (0.1s gap)
#    Vehicle 205: Lost at frame 358, found at 359 (0.0s gap)
#    Vehicle 213: Lost at frame 292, found at 295 (0.1s gap)
#    Vehicle 213: Lost at frame 300, found at 301 (0.0s gap)
#    Vehicle 213: Lost at frame 303, found at 306 (0.1s gap)
#    Vehicle 213: Lost at frame 320, found at 323 (0.1s gap)
#    Vehicle 213: Lost at frame 337, found at 338 (0.0s gap)
#    Vehicle 213: Lost at frame 347, found at 348 (0.0s gap)
#    Vehicle 213: Lost at frame 354, found at 355 (0.0s gap)
#    Vehicle 213: Lost at frame 356, found at 360 (0.1s gap)
#    Vehicle 213: Lost at frame 363, found at 365 (0.1s gap)
#    Vehicle 213: Lost at frame 368, found at 371 (0.1s gap)
#    Vehicle 213: Lost at frame 376, found at 377 (0.0s gap)
#    Vehicle 213: Lost at frame 392, found at 394 (0.1s gap)
#    Vehicle 213: Lost at frame 395, found at 397 (0.1s gap)
#    Vehicle 241: Lost at frame 330, found at 334 (0.1s gap)
#    Vehicle 241: Lost at frame 335, found at 339 (0.1s gap)
#    Vehicle 241: Lost at frame 340, found at 344 (0.1s gap)
#    Vehicle 215: Lost at frame 344, found at 353 (0.3s gap)
#    Vehicle 215: Lost at frame 359, found at 360 (0.0s gap)
#    Vehicle 215: Lost at frame 361, found at 362 (0.0s gap)
#    Vehicle 285: Lost at frame 390, found at 391 (0.0s gap)
#    Vehicle 297: Lost at frame 419, found at 420 (0.0s gap)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
